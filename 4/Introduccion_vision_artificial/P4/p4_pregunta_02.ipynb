# %%
#%%capture
#%tensorflow_version 2.x
# !pip install tensorflow==2.9.2
# Out:
# Requirement already satisfied: tensorflow==2.9.2 in /usr/local/lib/python3.10/dist-packages (2.9.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.6.3)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.12)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.68.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (3.12.1)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (2.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (24.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (3.19.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.17.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (2.9.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (0.37.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (2.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.17.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.9.2) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.2.2)

# %%
import tensorflow as tf
# !python --version                     # mostrar version de python
print('Tensorflow ' + tf.__version__) # mostrar version tensorflow
# Out:
# Python 3.10.12
# Tensorflow 2.9.2

# %%
import os, subprocess

# Montar Google Drive y crear carpetas
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

work_dir = '/content/work_dir'                    # directorio de trabajo en local (mas rapido)
dwld_dir = '/content/gdrive/My Drive/dwld_dir'    # directorio de descarga en Google drive personal
subprocess.call(["mkdir","-p",work_dir])          # crear directorio para trabajo
subprocess.call(["mkdir","-p",dwld_dir+'/dataset/'])  # crear directorio para dataset

os.chdir(dwld_dir+'/dataset/')                        # posicionarse en el directorio
# Descargar dataset scenes15 si no esta disponible
if os.path.isfile('./dataset_scenes15.zip') == False:
  # !wget http://www-vpu.eps.uam.es/~jcs/tsv/dataset_scenes15.zip

# Copiar el dataset al directorio local (mayor velocidad de lectura que en Gdrive)
# !cp /content/gdrive/My\ Drive/dwld_dir/dataset/dataset_scenes15.zip /content/work_dir/

os.chdir(work_dir)                        # posicionarse en el directorio
if os.path.isdir('./scenes15') == False:
  # !unzip -o -q dataset_scenes15.zip -d .

print('El dataset se encuentra descargado en el directorio {} \ny descomprimido en el directorio {} (usado para lectura de datos)'.format(dwld_dir, work_dir))
# Out:
# Mounted at /content/gdrive
# El dataset se encuentra descargado en el directorio /content/gdrive/My Drive/dwld_dir
# y descomprimido en el directorio /content/work_dir (usado para lectura de datos)

# %%
import tensorflow.keras.layers as layers
import tensorflow.keras.models as models
import tensorflow as tf
import pathlib
import numpy as np

dataset_dir = pathlib.Path(work_dir + '/scenes15/')

# Obtener etiquetas de clase y numero de clases
CLASS_NAMES = np.array([item.name for item in dataset_dir.glob('*')]) #clases son subdirectorios de '/train/'
NUM_CLASSES = len(CLASS_NAMES) # numero total de clases

# Crear ImageDataGenerator convirtiendo de uint8 a float32 en el rango [0,1].
img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.20)

acc = []
val_acc = []

loss = []
val_loss = []

img_sizes = [32, 64, 128, 224]
for img_size in img_sizes:
  # Obtenemos un iterador sobre los datos de entrenamiento del dataset
  # aplicando el ImageDataGenerator creado anteriormente
  BATCH_SIZE = 32 # numero de elementos procesados conjuntamente en cada iteracion
  IMG_HEIGHT = img_size
  IMG_WIDTH = img_size
  IMG_CHANNELS = 3
  train_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE,
                                            subset="training",
                                            shuffle=True,
                                            seed=0)

  test_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE,
                                            subset="validation",
                                            shuffle=True,
                                            seed=0)
  # definir modelo de red
  model = models.Sequential()

  # incluir capa convolucional C1
  model.add(layers.Conv2D(filters=6,
                          kernel_size=(3, 3),
                          strides = (1,1),
                          padding = 'valid',
                          activation='relu',
                          input_shape=(IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)))

  # incluir average pooling S2
  model.add(layers.AveragePooling2D())

  # incluir capa convolucional C3
  model.add(layers.Conv2D(filters=16,
                          kernel_size=(3, 3),
                          strides = (1,1),
                          padding = 'valid',
                          activation='relu'))

  # incluir average pooling S4
  model.add(layers.AveragePooling2D())

  # convertir el volumen de datos en vector fila para conectarlo con capa FC
  model.add(layers.Flatten())

  # incluir fully convolutional F5
  model.add(layers.Dense(units=120, activation='relu'))

  # incluir fully convolutional F6
  model.add(layers.Dense(units=84, activation='relu'))

  # incluir salida OUTPUT
  model.add(layers.Dense(units=NUM_CLASSES, activation = 'softmax'))


  # mostar resumen
  model.summary()

  import tensorflow.keras.optimizers as optimizers

  # definicion con optimizador con valores definidos por el usuario
  LEARNING_RATE = 0.01 # factor de aprendizaje
  model.compile(optimizer=optimizers.SGD(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
  import time
  stime = time.time() # medida inicial de tiempo

  EPOCHS = 50 # numero de epocas para entrenamiento

  #si tiene problemas al ejecutar con la GPU,
  # descomente la siguiente linea para utilizar la CPU
  # y comente la linea que selecciona la GPU
  #with tf.device('/CPU:0'):
  with tf.device('/GPU:0'):
    history = model.fit_generator(
        generator=train_data_gen,
        steps_per_epoch=train_data_gen.n // BATCH_SIZE,
        validation_data=test_data_gen,
        validation_steps=test_data_gen.n // BATCH_SIZE,
        epochs=EPOCHS,
        verbose=1
    )

  ftime = time.time() # medida final de tiempo
  print('Entrenamiento terminado {} secs' .format(ftime-stime))

  import time
  stime = time.time() # medida inicial de tiempo

  #si tiene problemas al ejecutar con la GPU,
  # descomente la siguiente linea para utilizar la CPU
  # y comente la linea que selecciona la GPU
  #with tf.device('/CPU:0'):
  with tf.device('/GPU:0'):
    test_loss, test_acc = model.evaluate_generator(generator=test_data_gen,
                                                  steps = test_data_gen.n // BATCH_SIZE,
                                                  verbose=1)

  ftime = time.time() # medida final de tiempo
  print('Test terminado {} secs' .format(ftime-stime))

  # rendimiento
  acc.append(history.history['accuracy'])         #entrenamiento
  val_acc.append(history.history['val_accuracy']) #validacion

  # funcion de perdidas
  loss.append(history.history['loss'])            #entrenamiento
  val_loss.append(history.history['val_loss'])    #validacion

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))

def show_results(title, items):
  for i in range(len(img_sizes)):
    plt.plot(range(EPOCHS), items[i], label=f'image size = {img_sizes[i]}x{img_sizes[i]}')

  plt.legend(loc='upper left')
  plt.xlabel('# epoca')
  plt.title(title)
  plt.show()


show_results("Rendimiento train (accuracy)", acc)
show_results("Rendimiento test (accuracy)", val_acc)
show_results("Pérdidas train (loss)", loss)
show_results("Pérdidas test (loss)", val_loss)
# Out:
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 6)         168
#
#  average_pooling2d (AverageP  (None, 15, 15, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 16)        880
#
#  average_pooling2d_1 (Averag  (None, 6, 6, 16)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 120)               69240
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 15)                1275
#
# =================================================================
# Total params: 81,727
# Trainable params: 81,727
# Non-trainable params: 0
# _________________________________________________________________
# <ipython-input-4-e988377b8a1e>:106: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/50
# 112/112 [==============================] - 8s 66ms/step - loss: 2.6979 - accuracy: 0.0890 - val_loss: 2.6904 - val_accuracy: 0.0868
# Epoch 2/50
# 112/112 [==============================] - 6s 58ms/step - loss: 2.6855 - accuracy: 0.1000 - val_loss: 2.6826 - val_accuracy: 0.1053
# Epoch 3/50
# 112/112 [==============================] - 6s 52ms/step - loss: 2.6757 - accuracy: 0.1017 - val_loss: 2.6766 - val_accuracy: 0.0914
# Epoch 4/50
# 112/112 [==============================] - 5s 46ms/step - loss: 2.6629 - accuracy: 0.1051 - val_loss: 2.6666 - val_accuracy: 0.0880
# Epoch 5/50
# 112/112 [==============================] - 5s 47ms/step - loss: 2.6420 - accuracy: 0.1084 - val_loss: 2.6457 - val_accuracy: 0.1007
# Epoch 6/50
# 112/112 [==============================] - 4s 39ms/step - loss: 2.6161 - accuracy: 0.1295 - val_loss: 2.6400 - val_accuracy: 0.1470
# Epoch 7/50
# 112/112 [==============================] - 7s 63ms/step - loss: 2.5791 - accuracy: 0.1565 - val_loss: 2.5927 - val_accuracy: 0.1435
# Epoch 8/50
# 112/112 [==============================] - 7s 65ms/step - loss: 2.5395 - accuracy: 0.1688 - val_loss: 2.5939 - val_accuracy: 0.1389
# Epoch 9/50
# 112/112 [==============================] - 7s 62ms/step - loss: 2.5032 - accuracy: 0.1907 - val_loss: 2.5569 - val_accuracy: 0.1736
# Epoch 10/50
# 112/112 [==============================] - 5s 47ms/step - loss: 2.4780 - accuracy: 0.1871 - val_loss: 2.5475 - val_accuracy: 0.1701
# Epoch 11/50
# 112/112 [==============================] - 5s 44ms/step - loss: 2.4606 - accuracy: 0.2048 - val_loss: 2.5250 - val_accuracy: 0.1644
# Epoch 12/50
# 112/112 [==============================] - 6s 54ms/step - loss: 2.4367 - accuracy: 0.2090 - val_loss: 2.5087 - val_accuracy: 0.1840
# Epoch 13/50
# 112/112 [==============================] - 7s 63ms/step - loss: 2.4126 - accuracy: 0.2174 - val_loss: 2.4896 - val_accuracy: 0.1898
# Epoch 14/50
# 112/112 [==============================] - 6s 52ms/step - loss: 2.3911 - accuracy: 0.2287 - val_loss: 2.4572 - val_accuracy: 0.2014
# Epoch 15/50
# 112/112 [==============================] - 7s 62ms/step - loss: 2.3723 - accuracy: 0.2253 - val_loss: 2.4936 - val_accuracy: 0.1956
# Epoch 16/50
# 112/112 [==============================] - 6s 50ms/step - loss: 2.3549 - accuracy: 0.2315 - val_loss: 2.4696 - val_accuracy: 0.1944
# Epoch 17/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.3284 - accuracy: 0.2430 - val_loss: 2.4438 - val_accuracy: 0.2176
# Epoch 18/50
# 112/112 [==============================] - 6s 50ms/step - loss: 2.3027 - accuracy: 0.2520 - val_loss: 2.4354 - val_accuracy: 0.2002
# Epoch 19/50
# 112/112 [==============================] - 5s 45ms/step - loss: 2.2775 - accuracy: 0.2565 - val_loss: 2.4315 - val_accuracy: 0.2072
# Epoch 20/50
# 112/112 [==============================] - 6s 50ms/step - loss: 2.2547 - accuracy: 0.2612 - val_loss: 2.4094 - val_accuracy: 0.2211
# Epoch 21/50
# 112/112 [==============================] - 6s 51ms/step - loss: 2.2181 - accuracy: 0.2857 - val_loss: 2.4313 - val_accuracy: 0.2025
# Epoch 22/50
# 112/112 [==============================] - 6s 50ms/step - loss: 2.1985 - accuracy: 0.2907 - val_loss: 2.3667 - val_accuracy: 0.2350
# Epoch 23/50
# 112/112 [==============================] - 8s 72ms/step - loss: 2.1769 - accuracy: 0.2890 - val_loss: 2.3273 - val_accuracy: 0.2454
# Epoch 24/50
# 112/112 [==============================] - 8s 70ms/step - loss: 2.1393 - accuracy: 0.2980 - val_loss: 2.3521 - val_accuracy: 0.2350
# Epoch 25/50
# 112/112 [==============================] - 6s 51ms/step - loss: 2.1169 - accuracy: 0.3034 - val_loss: 2.3038 - val_accuracy: 0.2569
# Epoch 26/50
# 112/112 [==============================] - 7s 58ms/step - loss: 2.0883 - accuracy: 0.3112 - val_loss: 2.3280 - val_accuracy: 0.2581
# Epoch 27/50
# 112/112 [==============================] - 6s 55ms/step - loss: 2.0584 - accuracy: 0.3244 - val_loss: 2.2834 - val_accuracy: 0.2523
# Epoch 28/50
# 112/112 [==============================] - 6s 56ms/step - loss: 2.0275 - accuracy: 0.3365 - val_loss: 2.2513 - val_accuracy: 0.2546
# Epoch 29/50
# 112/112 [==============================] - 6s 56ms/step - loss: 2.0129 - accuracy: 0.3396 - val_loss: 2.2207 - val_accuracy: 0.2697
# Epoch 30/50
# 112/112 [==============================] - 6s 56ms/step - loss: 1.9782 - accuracy: 0.3365 - val_loss: 2.2188 - val_accuracy: 0.3044
# Epoch 31/50
# 112/112 [==============================] - 6s 58ms/step - loss: 1.9392 - accuracy: 0.3615 - val_loss: 2.3480 - val_accuracy: 0.2523
# Epoch 32/50
# 112/112 [==============================] - 5s 47ms/step - loss: 1.9169 - accuracy: 0.3708 - val_loss: 2.1481 - val_accuracy: 0.3194
# Epoch 33/50
# 112/112 [==============================] - 6s 54ms/step - loss: 1.8996 - accuracy: 0.3787 - val_loss: 2.1969 - val_accuracy: 0.3009
# Epoch 34/50
# 112/112 [==============================] - 6s 52ms/step - loss: 1.8745 - accuracy: 0.3809 - val_loss: 2.2428 - val_accuracy: 0.2801
# Epoch 35/50
# 112/112 [==============================] - 8s 69ms/step - loss: 1.8549 - accuracy: 0.3885 - val_loss: 2.2275 - val_accuracy: 0.2882
# Epoch 36/50
# 112/112 [==============================] - 8s 72ms/step - loss: 1.8086 - accuracy: 0.4000 - val_loss: 2.1609 - val_accuracy: 0.3194
# Epoch 37/50
# 112/112 [==============================] - 6s 57ms/step - loss: 1.8015 - accuracy: 0.4042 - val_loss: 2.1398 - val_accuracy: 0.3252
# Epoch 38/50
# 112/112 [==============================] - 7s 64ms/step - loss: 1.7755 - accuracy: 0.4096 - val_loss: 2.1847 - val_accuracy: 0.2766
# Epoch 39/50
# 112/112 [==============================] - 7s 65ms/step - loss: 1.7687 - accuracy: 0.4146 - val_loss: 2.1051 - val_accuracy: 0.3171
# Epoch 40/50
# 112/112 [==============================] - 6s 50ms/step - loss: 1.7452 - accuracy: 0.4242 - val_loss: 2.1509 - val_accuracy: 0.3148
# Epoch 41/50
# 112/112 [==============================] - 6s 56ms/step - loss: 1.7091 - accuracy: 0.4351 - val_loss: 2.1229 - val_accuracy: 0.3148
# Epoch 42/50
# 112/112 [==============================] - 7s 64ms/step - loss: 1.6776 - accuracy: 0.4421 - val_loss: 2.4612 - val_accuracy: 0.2662
# Epoch 43/50
# 112/112 [==============================] - 5s 48ms/step - loss: 1.6690 - accuracy: 0.4517 - val_loss: 2.1682 - val_accuracy: 0.3032
# Epoch 44/50
# 112/112 [==============================] - 7s 58ms/step - loss: 1.6356 - accuracy: 0.4528 - val_loss: 2.1234 - val_accuracy: 0.3252
# Epoch 45/50
# 112/112 [==============================] - 6s 47ms/step - loss: 1.6246 - accuracy: 0.4590 - val_loss: 2.2325 - val_accuracy: 0.2928
# Epoch 46/50
# 112/112 [==============================] - 8s 71ms/step - loss: 1.5982 - accuracy: 0.4705 - val_loss: 2.1439 - val_accuracy: 0.3021
# Epoch 47/50
# 112/112 [==============================] - 4s 40ms/step - loss: 1.5639 - accuracy: 0.4750 - val_loss: 2.1267 - val_accuracy: 0.3148
# Epoch 48/50
# 112/112 [==============================] - 6s 56ms/step - loss: 1.5316 - accuracy: 0.4961 - val_loss: 2.2393 - val_accuracy: 0.2801
# Epoch 49/50
# 112/112 [==============================] - 7s 64ms/step - loss: 1.5383 - accuracy: 0.4961 - val_loss: 2.1792 - val_accuracy: 0.3113
# Epoch 50/50
# 112/112 [==============================] - 6s 57ms/step - loss: 1.4934 - accuracy: 0.5014 - val_loss: 2.1984 - val_accuracy: 0.3125
# Entrenamiento terminado 324.715856552124 secs
#  1/27 [>.............................] - ETA: 1s - loss: 1.8441 - accuracy: 0.4375
# <ipython-input-4-e988377b8a1e>:126: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_acc = model.evaluate_generator(generator=test_data_gen,
# 27/27 [==============================] - 1s 33ms/step - loss: 2.1933 - accuracy: 0.3160
# Test terminado 0.9816443920135498 secs
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 62, 62, 6)         168
#
#  average_pooling2d_2 (Averag  (None, 31, 31, 6)        0
#  ePooling2D)
#
#  conv2d_3 (Conv2D)           (None, 29, 29, 16)        880
#
#  average_pooling2d_3 (Averag  (None, 14, 14, 16)       0
#  ePooling2D)
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_3 (Dense)             (None, 120)               376440
#
#  dense_4 (Dense)             (None, 84)                10164
#
#  dense_5 (Dense)             (None, 15)                1275
#
# =================================================================
# Total params: 388,927
# Trainable params: 388,927
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# <ipython-input-4-e988377b8a1e>:106: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 112/112 [==============================] - 8s 68ms/step - loss: 2.7032 - accuracy: 0.0705 - val_loss: 2.6965 - val_accuracy: 0.0914
# Epoch 2/50
# 112/112 [==============================] - 6s 53ms/step - loss: 2.6904 - accuracy: 0.0831 - val_loss: 2.6828 - val_accuracy: 0.0926
# Epoch 3/50
# 112/112 [==============================] - 6s 55ms/step - loss: 2.6727 - accuracy: 0.0949 - val_loss: 2.6671 - val_accuracy: 0.0926
# Epoch 4/50
# 112/112 [==============================] - 8s 70ms/step - loss: 2.6383 - accuracy: 0.1219 - val_loss: 2.6280 - val_accuracy: 0.1181
# Epoch 5/50
# 112/112 [==============================] - 6s 54ms/step - loss: 2.5741 - accuracy: 0.1579 - val_loss: 2.5855 - val_accuracy: 0.1470
# Epoch 6/50
# 112/112 [==============================] - 6s 55ms/step - loss: 2.5083 - accuracy: 0.1874 - val_loss: 2.5461 - val_accuracy: 0.1678
# Epoch 7/50
# 112/112 [==============================] - 7s 60ms/step - loss: 2.4515 - accuracy: 0.1969 - val_loss: 2.4936 - val_accuracy: 0.1713
# Epoch 8/50
# 112/112 [==============================] - 6s 50ms/step - loss: 2.4135 - accuracy: 0.2121 - val_loss: 2.4701 - val_accuracy: 0.1956
# Epoch 9/50
# 112/112 [==============================] - 6s 51ms/step - loss: 2.3633 - accuracy: 0.2270 - val_loss: 2.4681 - val_accuracy: 0.2060
# Epoch 10/50
# 112/112 [==============================] - 6s 56ms/step - loss: 2.3317 - accuracy: 0.2399 - val_loss: 2.4411 - val_accuracy: 0.2060
# Epoch 11/50
# 112/112 [==============================] - 7s 62ms/step - loss: 2.2760 - accuracy: 0.2587 - val_loss: 2.3928 - val_accuracy: 0.2280
# Epoch 12/50
# 112/112 [==============================] - 6s 53ms/step - loss: 2.2510 - accuracy: 0.2677 - val_loss: 2.3708 - val_accuracy: 0.2431
# Epoch 13/50
# 112/112 [==============================] - 6s 56ms/step - loss: 2.2090 - accuracy: 0.2907 - val_loss: 2.3741 - val_accuracy: 0.2488
# Epoch 14/50
# 112/112 [==============================] - 7s 60ms/step - loss: 2.1658 - accuracy: 0.2952 - val_loss: 2.3246 - val_accuracy: 0.2500
# Epoch 15/50
# 112/112 [==============================] - 7s 61ms/step - loss: 2.1423 - accuracy: 0.2992 - val_loss: 2.3256 - val_accuracy: 0.2465
# Epoch 16/50
# 112/112 [==============================] - 7s 62ms/step - loss: 2.0916 - accuracy: 0.3202 - val_loss: 2.3252 - val_accuracy: 0.2604
# Epoch 17/50
# 112/112 [==============================] - 9s 79ms/step - loss: 2.0882 - accuracy: 0.3295 - val_loss: 2.3389 - val_accuracy: 0.2477
# Epoch 18/50
# 112/112 [==============================] - 6s 54ms/step - loss: 2.0150 - accuracy: 0.3385 - val_loss: 2.2445 - val_accuracy: 0.2778
# Epoch 19/50
# 112/112 [==============================] - 6s 55ms/step - loss: 1.9770 - accuracy: 0.3545 - val_loss: 2.2202 - val_accuracy: 0.2674
# Epoch 20/50
# 112/112 [==============================] - 6s 56ms/step - loss: 1.9220 - accuracy: 0.3750 - val_loss: 2.2161 - val_accuracy: 0.2812
# Epoch 21/50
# 112/112 [==============================] - 6s 56ms/step - loss: 1.9014 - accuracy: 0.3792 - val_loss: 2.1755 - val_accuracy: 0.2951
# Epoch 22/50
# 112/112 [==============================] - 7s 61ms/step - loss: 1.8510 - accuracy: 0.4022 - val_loss: 2.1786 - val_accuracy: 0.2870
# Epoch 23/50
# 112/112 [==============================] - 8s 69ms/step - loss: 1.8086 - accuracy: 0.4180 - val_loss: 2.1184 - val_accuracy: 0.3056
# Epoch 24/50
# 112/112 [==============================] - 9s 80ms/step - loss: 1.7960 - accuracy: 0.4166 - val_loss: 2.3555 - val_accuracy: 0.2731
# Epoch 25/50
# 112/112 [==============================] - 6s 54ms/step - loss: 1.7181 - accuracy: 0.4430 - val_loss: 2.3372 - val_accuracy: 0.2674
# Epoch 26/50
# 112/112 [==============================] - 8s 71ms/step - loss: 1.6901 - accuracy: 0.4576 - val_loss: 2.2177 - val_accuracy: 0.2755
# Epoch 27/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.6193 - accuracy: 0.4702 - val_loss: 2.0517 - val_accuracy: 0.3241
# Epoch 28/50
# 112/112 [==============================] - 8s 70ms/step - loss: 1.5676 - accuracy: 0.4947 - val_loss: 2.1087 - val_accuracy: 0.3368
# Epoch 29/50
# 112/112 [==============================] - 5s 48ms/step - loss: 1.5534 - accuracy: 0.4944 - val_loss: 2.1713 - val_accuracy: 0.3171
# Epoch 30/50
# 112/112 [==============================] - 7s 59ms/step - loss: 1.4831 - accuracy: 0.5157 - val_loss: 1.9895 - val_accuracy: 0.3727
# Epoch 31/50
# 112/112 [==============================] - 7s 66ms/step - loss: 1.4628 - accuracy: 0.5202 - val_loss: 2.0648 - val_accuracy: 0.3345
# Epoch 32/50
# 112/112 [==============================] - 6s 50ms/step - loss: 1.3879 - accuracy: 0.5486 - val_loss: 2.1276 - val_accuracy: 0.3472
# Epoch 33/50
# 112/112 [==============================] - 6s 54ms/step - loss: 1.3682 - accuracy: 0.5539 - val_loss: 2.0066 - val_accuracy: 0.3484
# Epoch 34/50
# 112/112 [==============================] - 6s 56ms/step - loss: 1.3172 - accuracy: 0.5719 - val_loss: 2.0162 - val_accuracy: 0.3669
# Epoch 35/50
# 112/112 [==============================] - 5s 49ms/step - loss: 1.2914 - accuracy: 0.5711 - val_loss: 2.1716 - val_accuracy: 0.3275
# Epoch 36/50
# 112/112 [==============================] - 5s 48ms/step - loss: 1.2405 - accuracy: 0.5947 - val_loss: 2.1973 - val_accuracy: 0.3206
# Epoch 37/50
# 112/112 [==============================] - 6s 53ms/step - loss: 1.2186 - accuracy: 0.5994 - val_loss: 2.0909 - val_accuracy: 0.3785
# Epoch 38/50
# 112/112 [==============================] - 8s 70ms/step - loss: 1.1662 - accuracy: 0.6183 - val_loss: 1.9681 - val_accuracy: 0.3773
# Epoch 39/50
# 112/112 [==============================] - 6s 50ms/step - loss: 1.1314 - accuracy: 0.6301 - val_loss: 2.0767 - val_accuracy: 0.3657
# Epoch 40/50
# 112/112 [==============================] - 8s 71ms/step - loss: 1.0954 - accuracy: 0.6410 - val_loss: 2.0839 - val_accuracy: 0.3438
# Epoch 41/50
# 112/112 [==============================] - 8s 71ms/step - loss: 1.0920 - accuracy: 0.6441 - val_loss: 2.1336 - val_accuracy: 0.3426
# Epoch 42/50
# 112/112 [==============================] - 7s 63ms/step - loss: 1.0157 - accuracy: 0.6657 - val_loss: 2.1566 - val_accuracy: 0.3924
# Epoch 43/50
# 112/112 [==============================] - 6s 56ms/step - loss: 0.9822 - accuracy: 0.6815 - val_loss: 2.2356 - val_accuracy: 0.3657
# Epoch 44/50
# 112/112 [==============================] - 6s 54ms/step - loss: 0.9260 - accuracy: 0.6944 - val_loss: 2.1105 - val_accuracy: 0.3819
# Epoch 45/50
# 112/112 [==============================] - 6s 58ms/step - loss: 0.9978 - accuracy: 0.6798 - val_loss: 2.1114 - val_accuracy: 0.3495
# Epoch 46/50
# 112/112 [==============================] - 7s 65ms/step - loss: 0.8609 - accuracy: 0.7278 - val_loss: 2.1526 - val_accuracy: 0.3623
# Epoch 47/50
# 112/112 [==============================] - 9s 81ms/step - loss: 0.8278 - accuracy: 0.7213 - val_loss: 2.2052 - val_accuracy: 0.3553
# Epoch 48/50
# 112/112 [==============================] - 7s 66ms/step - loss: 0.7551 - accuracy: 0.7551 - val_loss: 2.2029 - val_accuracy: 0.4016
# Epoch 49/50
# 112/112 [==============================] - 6s 54ms/step - loss: 0.7401 - accuracy: 0.7632 - val_loss: 2.1830 - val_accuracy: 0.3796
# Epoch 50/50
# 112/112 [==============================] - 7s 60ms/step - loss: 0.7175 - accuracy: 0.7654 - val_loss: 2.2490 - val_accuracy: 0.3808
# Entrenamiento terminado 339.7120819091797 secs
#  1/27 [>.............................] - ETA: 1s - loss: 2.2328 - accuracy: 0.3125
# <ipython-input-4-e988377b8a1e>:126: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_acc = model.evaluate_generator(generator=test_data_gen,
# 27/27 [==============================] - 1s 34ms/step - loss: 2.2198 - accuracy: 0.3831
# Test terminado 1.0255615711212158 secs
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 126, 126, 6)       168
#
#  average_pooling2d_4 (Averag  (None, 63, 63, 6)        0
#  ePooling2D)
#
#  conv2d_5 (Conv2D)           (None, 61, 61, 16)        880
#
#  average_pooling2d_5 (Averag  (None, 30, 30, 16)       0
#  ePooling2D)
#
#  flatten_2 (Flatten)         (None, 14400)             0
#
#  dense_6 (Dense)             (None, 120)               1728120
#
#  dense_7 (Dense)             (None, 84)                10164
#
#  dense_8 (Dense)             (None, 15)                1275
#
# =================================================================
# Total params: 1,740,607
# Trainable params: 1,740,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# <ipython-input-4-e988377b8a1e>:106: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 112/112 [==============================] - 9s 78ms/step - loss: 2.6636 - accuracy: 0.1042 - val_loss: 2.6413 - val_accuracy: 0.0891
# Epoch 2/50
# 112/112 [==============================] - 9s 84ms/step - loss: 2.5633 - accuracy: 0.1506 - val_loss: 2.5453 - val_accuracy: 0.1505
# Epoch 3/50
# 112/112 [==============================] - 9s 83ms/step - loss: 2.4798 - accuracy: 0.1826 - val_loss: 2.5567 - val_accuracy: 0.1736
# Epoch 4/50
# 112/112 [==============================] - 9s 85ms/step - loss: 2.4072 - accuracy: 0.2163 - val_loss: 2.4851 - val_accuracy: 0.2164
# Epoch 5/50
# 112/112 [==============================] - 9s 79ms/step - loss: 2.3443 - accuracy: 0.2374 - val_loss: 2.4453 - val_accuracy: 0.2118
# Epoch 6/50
# 112/112 [==============================] - 10s 86ms/step - loss: 2.2900 - accuracy: 0.2525 - val_loss: 2.4534 - val_accuracy: 0.2211
# Epoch 7/50
# 112/112 [==============================] - 9s 84ms/step - loss: 2.2317 - accuracy: 0.2778 - val_loss: 2.4286 - val_accuracy: 0.2338
# Epoch 8/50
# 112/112 [==============================] - 9s 80ms/step - loss: 2.1909 - accuracy: 0.2885 - val_loss: 2.4188 - val_accuracy: 0.2176
# Epoch 9/50
# 112/112 [==============================] - 8s 71ms/step - loss: 2.1295 - accuracy: 0.3107 - val_loss: 2.4993 - val_accuracy: 0.2176
# Epoch 10/50
# 112/112 [==============================] - 9s 77ms/step - loss: 2.0716 - accuracy: 0.3354 - val_loss: 2.3785 - val_accuracy: 0.2373
# Epoch 11/50
# 112/112 [==============================] - 9s 77ms/step - loss: 2.0119 - accuracy: 0.3551 - val_loss: 2.3333 - val_accuracy: 0.2546
# Epoch 12/50
# 112/112 [==============================] - 10s 88ms/step - loss: 1.9439 - accuracy: 0.3742 - val_loss: 2.3157 - val_accuracy: 0.2558
# Epoch 13/50
# 112/112 [==============================] - 11s 96ms/step - loss: 1.8881 - accuracy: 0.3933 - val_loss: 2.2921 - val_accuracy: 0.2836
# Epoch 14/50
# 112/112 [==============================] - 7s 66ms/step - loss: 1.8102 - accuracy: 0.4239 - val_loss: 2.4211 - val_accuracy: 0.2488
# Epoch 15/50
# 112/112 [==============================] - 10s 88ms/step - loss: 1.7469 - accuracy: 0.4404 - val_loss: 2.3196 - val_accuracy: 0.2558
# Epoch 16/50
# 112/112 [==============================] - 9s 76ms/step - loss: 1.6644 - accuracy: 0.4615 - val_loss: 2.2315 - val_accuracy: 0.3079
# Epoch 17/50
# 112/112 [==============================] - 9s 81ms/step - loss: 1.5862 - accuracy: 0.4860 - val_loss: 2.3423 - val_accuracy: 0.2685
# Epoch 18/50
# 112/112 [==============================] - 10s 90ms/step - loss: 1.5094 - accuracy: 0.5132 - val_loss: 2.2131 - val_accuracy: 0.3067
# Epoch 19/50
# 112/112 [==============================] - 8s 70ms/step - loss: 1.4284 - accuracy: 0.5413 - val_loss: 2.3210 - val_accuracy: 0.2894
# Epoch 20/50
# 112/112 [==============================] - 7s 65ms/step - loss: 1.3473 - accuracy: 0.5618 - val_loss: 2.2282 - val_accuracy: 0.3113
# Epoch 21/50
# 112/112 [==============================] - 10s 90ms/step - loss: 1.2634 - accuracy: 0.5958 - val_loss: 2.2287 - val_accuracy: 0.3299
# Epoch 22/50
# 112/112 [==============================] - 9s 84ms/step - loss: 1.1900 - accuracy: 0.6149 - val_loss: 2.3741 - val_accuracy: 0.3079
# Epoch 23/50
# 112/112 [==============================] - 7s 62ms/step - loss: 1.0746 - accuracy: 0.6615 - val_loss: 2.3914 - val_accuracy: 0.3090
# Epoch 24/50
# 112/112 [==============================] - 8s 74ms/step - loss: 0.9634 - accuracy: 0.6938 - val_loss: 2.3466 - val_accuracy: 0.3194
# Epoch 25/50
# 112/112 [==============================] - 6s 55ms/step - loss: 0.8337 - accuracy: 0.7382 - val_loss: 2.7244 - val_accuracy: 0.2789
# Epoch 26/50
# 112/112 [==============================] - 9s 81ms/step - loss: 0.7716 - accuracy: 0.7677 - val_loss: 2.3131 - val_accuracy: 0.3275
# Epoch 27/50
# 112/112 [==============================] - 9s 77ms/step - loss: 0.6477 - accuracy: 0.8011 - val_loss: 2.5791 - val_accuracy: 0.3252
# Epoch 28/50
# 112/112 [==============================] - 8s 70ms/step - loss: 0.5576 - accuracy: 0.8388 - val_loss: 2.5970 - val_accuracy: 0.3218
# Epoch 29/50
# 112/112 [==============================] - 8s 76ms/step - loss: 0.4378 - accuracy: 0.8680 - val_loss: 2.6479 - val_accuracy: 0.3310
# Epoch 30/50
# 112/112 [==============================] - 8s 76ms/step - loss: 0.3627 - accuracy: 0.8966 - val_loss: 2.7451 - val_accuracy: 0.3275
# Epoch 31/50
# 112/112 [==============================] - 6s 55ms/step - loss: 0.2904 - accuracy: 0.9211 - val_loss: 2.7757 - val_accuracy: 0.3565
# Epoch 32/50
# 112/112 [==============================] - 9s 77ms/step - loss: 0.2604 - accuracy: 0.9326 - val_loss: 3.0395 - val_accuracy: 0.3275
# Epoch 33/50
# 112/112 [==============================] - 9s 84ms/step - loss: 0.1866 - accuracy: 0.9492 - val_loss: 3.0666 - val_accuracy: 0.3449
# Epoch 34/50
# 112/112 [==============================] - 9s 82ms/step - loss: 0.1499 - accuracy: 0.9607 - val_loss: 3.1565 - val_accuracy: 0.3287
# Epoch 35/50
# 112/112 [==============================] - 9s 84ms/step - loss: 0.3351 - accuracy: 0.9222 - val_loss: 2.7850 - val_accuracy: 0.3171
# Epoch 36/50
# 112/112 [==============================] - 7s 63ms/step - loss: 0.1450 - accuracy: 0.9657 - val_loss: 3.3142 - val_accuracy: 0.3380
# Epoch 37/50
# 112/112 [==============================] - 6s 55ms/step - loss: 0.1004 - accuracy: 0.9744 - val_loss: 3.4660 - val_accuracy: 0.3588
# Epoch 38/50
# 112/112 [==============================] - 8s 73ms/step - loss: 0.0653 - accuracy: 0.9857 - val_loss: 3.5945 - val_accuracy: 0.3414
# Epoch 39/50
# 112/112 [==============================] - 8s 71ms/step - loss: 0.1294 - accuracy: 0.9728 - val_loss: 3.3853 - val_accuracy: 0.3380
# Epoch 40/50
# 112/112 [==============================] - 10s 92ms/step - loss: 0.0608 - accuracy: 0.9888 - val_loss: 3.6030 - val_accuracy: 0.3623
# Epoch 41/50
# 112/112 [==============================] - 7s 60ms/step - loss: 0.0412 - accuracy: 0.9921 - val_loss: 3.8061 - val_accuracy: 0.3565
# Epoch 42/50
# 112/112 [==============================] - 8s 70ms/step - loss: 0.0562 - accuracy: 0.9860 - val_loss: 3.7650 - val_accuracy: 0.3657
# Epoch 43/50
# 112/112 [==============================] - 9s 80ms/step - loss: 0.0331 - accuracy: 0.9938 - val_loss: 3.9225 - val_accuracy: 0.3472
# Epoch 44/50
# 112/112 [==============================] - 8s 69ms/step - loss: 0.0294 - accuracy: 0.9944 - val_loss: 3.9327 - val_accuracy: 0.3634
# Epoch 45/50
# 112/112 [==============================] - 7s 61ms/step - loss: 0.0255 - accuracy: 0.9944 - val_loss: 4.0912 - val_accuracy: 0.3576
# Epoch 46/50
# 112/112 [==============================] - 8s 76ms/step - loss: 0.0262 - accuracy: 0.9961 - val_loss: 4.0898 - val_accuracy: 0.3623
# Epoch 47/50
# 112/112 [==============================] - 8s 72ms/step - loss: 0.0196 - accuracy: 0.9966 - val_loss: 4.1362 - val_accuracy: 0.3565
# Epoch 48/50
# 112/112 [==============================] - 7s 64ms/step - loss: 0.0213 - accuracy: 0.9975 - val_loss: 4.1680 - val_accuracy: 0.3762
# Epoch 49/50
# 112/112 [==============================] - 10s 88ms/step - loss: 0.0200 - accuracy: 0.9966 - val_loss: 4.1679 - val_accuracy: 0.3634
# Epoch 50/50
# 112/112 [==============================] - 9s 78ms/step - loss: 0.0224 - accuracy: 0.9961 - val_loss: 4.1079 - val_accuracy: 0.3750
# Entrenamiento terminado 437.65329241752625 secs
#  1/27 [>.............................] - ETA: 1s - loss: 3.1598 - accuracy: 0.3438
# <ipython-input-4-e988377b8a1e>:126: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_acc = model.evaluate_generator(generator=test_data_gen,
# 27/27 [==============================] - 2s 62ms/step - loss: 4.0881 - accuracy: 0.3773
# Test terminado 1.7728652954101562 secs
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 222, 222, 6)       168
#
#  average_pooling2d_6 (Averag  (None, 111, 111, 6)      0
#  ePooling2D)
#
#  conv2d_7 (Conv2D)           (None, 109, 109, 16)      880
#
#  average_pooling2d_7 (Averag  (None, 54, 54, 16)       0
#  ePooling2D)
#
#  flatten_3 (Flatten)         (None, 46656)             0
#
#  dense_9 (Dense)             (None, 120)               5598840
#
#  dense_10 (Dense)            (None, 84)                10164
#
#  dense_11 (Dense)            (None, 15)                1275
#
# =================================================================
# Total params: 5,611,327
# Trainable params: 5,611,327
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# <ipython-input-4-e988377b8a1e>:106: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 112/112 [==============================] - 12s 102ms/step - loss: 2.6639 - accuracy: 0.1006 - val_loss: 2.6787 - val_accuracy: 0.0938
# Epoch 2/50
# 112/112 [==============================] - 16s 139ms/step - loss: 2.5542 - accuracy: 0.1581 - val_loss: 2.5530 - val_accuracy: 0.1447
# Epoch 3/50
# 112/112 [==============================] - 14s 123ms/step - loss: 2.4600 - accuracy: 0.1963 - val_loss: 2.4758 - val_accuracy: 0.1991
# Epoch 4/50
# 112/112 [==============================] - 14s 123ms/step - loss: 2.3634 - accuracy: 0.2357 - val_loss: 2.4665 - val_accuracy: 0.2141
# Epoch 5/50
# 112/112 [==============================] - 13s 113ms/step - loss: 2.2886 - accuracy: 0.2545 - val_loss: 2.3694 - val_accuracy: 0.2373
# Epoch 6/50
# 112/112 [==============================] - 12s 109ms/step - loss: 2.2093 - accuracy: 0.2798 - val_loss: 2.3720 - val_accuracy: 0.2431
# Epoch 7/50
# 112/112 [==============================] - 14s 125ms/step - loss: 2.1297 - accuracy: 0.3129 - val_loss: 2.3520 - val_accuracy: 0.2431
# Epoch 8/50
# 112/112 [==============================] - 16s 141ms/step - loss: 2.0562 - accuracy: 0.3393 - val_loss: 2.3914 - val_accuracy: 0.2442
# Epoch 9/50
# 112/112 [==============================] - 14s 128ms/step - loss: 1.9677 - accuracy: 0.3669 - val_loss: 2.3100 - val_accuracy: 0.2697
# Epoch 10/50
# 112/112 [==============================] - 15s 132ms/step - loss: 1.8695 - accuracy: 0.4104 - val_loss: 2.3579 - val_accuracy: 0.2627
# Epoch 11/50
# 112/112 [==============================] - 15s 135ms/step - loss: 1.7824 - accuracy: 0.4267 - val_loss: 2.3483 - val_accuracy: 0.2894
# Epoch 12/50
# 112/112 [==============================] - 15s 139ms/step - loss: 1.6899 - accuracy: 0.4688 - val_loss: 2.3901 - val_accuracy: 0.2731
# Epoch 13/50
# 112/112 [==============================] - 14s 121ms/step - loss: 1.5477 - accuracy: 0.5076 - val_loss: 2.4938 - val_accuracy: 0.2731
# Epoch 14/50
# 112/112 [==============================] - 13s 119ms/step - loss: 1.3995 - accuracy: 0.5525 - val_loss: 2.2015 - val_accuracy: 0.3090
# Epoch 15/50
# 112/112 [==============================] - 12s 106ms/step - loss: 1.2157 - accuracy: 0.6112 - val_loss: 2.2663 - val_accuracy: 0.3368
# Epoch 16/50
# 112/112 [==============================] - 14s 125ms/step - loss: 1.0803 - accuracy: 0.6520 - val_loss: 2.2540 - val_accuracy: 0.3530
# Epoch 17/50
# 112/112 [==============================] - 16s 142ms/step - loss: 0.8867 - accuracy: 0.7174 - val_loss: 2.2200 - val_accuracy: 0.3646
# Epoch 18/50
# 112/112 [==============================] - 13s 113ms/step - loss: 0.6910 - accuracy: 0.7924 - val_loss: 2.4267 - val_accuracy: 0.3403
# Epoch 19/50
# 112/112 [==============================] - 14s 125ms/step - loss: 0.5387 - accuracy: 0.8368 - val_loss: 2.3058 - val_accuracy: 0.3600
# Epoch 20/50
# 112/112 [==============================] - 12s 109ms/step - loss: 0.3972 - accuracy: 0.8924 - val_loss: 2.2658 - val_accuracy: 0.3889
# Epoch 21/50
# 112/112 [==============================] - 13s 115ms/step - loss: 0.2189 - accuracy: 0.9421 - val_loss: 2.6026 - val_accuracy: 0.3843
# Epoch 22/50
# 112/112 [==============================] - 13s 114ms/step - loss: 0.2158 - accuracy: 0.9435 - val_loss: 2.4850 - val_accuracy: 0.3993
# Epoch 23/50
# 112/112 [==============================] - 15s 131ms/step - loss: 0.1294 - accuracy: 0.9685 - val_loss: 2.6049 - val_accuracy: 0.4178
# Epoch 24/50
# 112/112 [==============================] - 12s 104ms/step - loss: 0.0684 - accuracy: 0.9862 - val_loss: 2.8836 - val_accuracy: 0.4062
# Epoch 25/50
# 112/112 [==============================] - 14s 127ms/step - loss: 0.0561 - accuracy: 0.9882 - val_loss: 3.0039 - val_accuracy: 0.4005
# Epoch 26/50
# 112/112 [==============================] - 13s 117ms/step - loss: 0.2232 - accuracy: 0.9494 - val_loss: 2.6538 - val_accuracy: 0.3646
# Epoch 27/50
# 112/112 [==============================] - 12s 111ms/step - loss: 0.0581 - accuracy: 0.9902 - val_loss: 2.9146 - val_accuracy: 0.4028
# Epoch 28/50
# 112/112 [==============================] - 15s 138ms/step - loss: 0.0588 - accuracy: 0.9896 - val_loss: 2.7777 - val_accuracy: 0.4086
# Epoch 29/50
# 112/112 [==============================] - 15s 133ms/step - loss: 0.0321 - accuracy: 0.9958 - val_loss: 3.1147 - val_accuracy: 0.4062
# Epoch 30/50
# 112/112 [==============================] - 13s 116ms/step - loss: 0.0191 - accuracy: 0.9978 - val_loss: 3.1476 - val_accuracy: 0.4201
# Epoch 31/50
# 112/112 [==============================] - 12s 110ms/step - loss: 0.0169 - accuracy: 0.9986 - val_loss: 3.2508 - val_accuracy: 0.4132
# Epoch 32/50
# 112/112 [==============================] - 12s 106ms/step - loss: 0.0124 - accuracy: 0.9980 - val_loss: 3.3142 - val_accuracy: 0.4132
# Epoch 33/50
# 112/112 [==============================] - 12s 110ms/step - loss: 0.0151 - accuracy: 0.9986 - val_loss: 3.4235 - val_accuracy: 0.4109
# Epoch 34/50
# 112/112 [==============================] - 12s 111ms/step - loss: 0.0256 - accuracy: 0.9941 - val_loss: 2.9445 - val_accuracy: 0.3970
# Epoch 35/50
# 112/112 [==============================] - 16s 146ms/step - loss: 0.1526 - accuracy: 0.9725 - val_loss: 2.5943 - val_accuracy: 0.3137
# Epoch 36/50
# 112/112 [==============================] - 14s 126ms/step - loss: 0.2737 - accuracy: 0.9379 - val_loss: 2.8085 - val_accuracy: 0.4248
# Epoch 37/50
# 112/112 [==============================] - 14s 125ms/step - loss: 0.0176 - accuracy: 0.9997 - val_loss: 3.0845 - val_accuracy: 0.4132
# Epoch 38/50
# 112/112 [==============================] - 17s 156ms/step - loss: 0.0111 - accuracy: 0.9994 - val_loss: 3.2543 - val_accuracy: 0.4236
# Epoch 39/50
# 112/112 [==============================] - 16s 144ms/step - loss: 0.0078 - accuracy: 0.9997 - val_loss: 3.4172 - val_accuracy: 0.4201
# Epoch 40/50
# 112/112 [==============================] - 13s 119ms/step - loss: 0.0060 - accuracy: 0.9997 - val_loss: 3.3250 - val_accuracy: 0.4132
# Epoch 41/50
# 112/112 [==============================] - 16s 141ms/step - loss: 0.0045 - accuracy: 0.9997 - val_loss: 3.4127 - val_accuracy: 0.4248
# Epoch 42/50
# 112/112 [==============================] - 14s 123ms/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 3.4550 - val_accuracy: 0.4213
# Epoch 43/50
# 112/112 [==============================] - 14s 126ms/step - loss: 0.0037 - accuracy: 0.9997 - val_loss: 3.4713 - val_accuracy: 0.4236
# Epoch 44/50
# 112/112 [==============================] - 12s 111ms/step - loss: 0.0034 - accuracy: 0.9997 - val_loss: 3.5870 - val_accuracy: 0.4051
# Epoch 45/50
# 112/112 [==============================] - 12s 108ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 3.5645 - val_accuracy: 0.4097
# Epoch 46/50
# 112/112 [==============================] - 12s 107ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 3.5936 - val_accuracy: 0.4201
# Epoch 47/50
# 112/112 [==============================] - 14s 129ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 3.6262 - val_accuracy: 0.4086
# Epoch 48/50
# 112/112 [==============================] - 13s 120ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 3.6961 - val_accuracy: 0.4051
# Epoch 49/50
# 112/112 [==============================] - 15s 131ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 3.6973 - val_accuracy: 0.4167
# Epoch 50/50
# 112/112 [==============================] - 12s 110ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 3.6839 - val_accuracy: 0.4074
# Entrenamiento terminado 692.2823402881622 secs
#  1/27 [>.............................] - ETA: 2s - loss: 4.4556 - accuracy: 0.3125
# <ipython-input-4-e988377b8a1e>:126: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_acc = model.evaluate_generator(generator=test_data_gen,
# 27/27 [==============================] - 3s 108ms/step - loss: 3.7334 - accuracy: 0.4051
# Test terminado 2.9995803833007812 secs
