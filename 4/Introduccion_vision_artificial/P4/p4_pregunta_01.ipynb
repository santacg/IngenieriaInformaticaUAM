# %%
#%%capture
#%tensorflow_version 2.x
# !pip install tensorflow==2.9.2
# Out:
# Requirement already satisfied: tensorflow==2.9.2 in /usr/local/lib/python3.10/dist-packages (2.9.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.6.3)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.12)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.68.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (3.12.1)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (2.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (24.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (3.19.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.17.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (2.9.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (0.37.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (2.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.17.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.9.2) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.2.2)

# %%
import tensorflow as tf
# !python --version                     # mostrar version de python
print('Tensorflow ' + tf.__version__) # mostrar version tensorflow
# Out:
# Python 3.10.12
# Tensorflow 2.9.2

# %%
import os, subprocess

# Montar Google Drive y crear carpetas
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

work_dir = '/content/work_dir'                    # directorio de trabajo en local (mas rapido)
dwld_dir = '/content/gdrive/My Drive/dwld_dir'    # directorio de descarga en Google drive personal
subprocess.call(["mkdir","-p",work_dir])          # crear directorio para trabajo
subprocess.call(["mkdir","-p",dwld_dir+'/dataset/'])  # crear directorio para dataset

os.chdir(dwld_dir+'/dataset/')                        # posicionarse en el directorio
# Descargar dataset scenes15 si no esta disponible
if os.path.isfile('./dataset_scenes15.zip') == False:
  # !wget http://www-vpu.eps.uam.es/~jcs/tsv/dataset_scenes15.zip

# Copiar el dataset al directorio local (mayor velocidad de lectura que en Gdrive)
# !cp /content/gdrive/My\ Drive/dwld_dir/dataset/dataset_scenes15.zip /content/work_dir/

os.chdir(work_dir)                        # posicionarse en el directorio
if os.path.isdir('./scenes15') == False:
  # !unzip -o -q dataset_scenes15.zip -d .

print('El dataset se encuentra descargado en el directorio {} \ny descomprimido en el directorio {} (usado para lectura de datos)'.format(dwld_dir, work_dir))
# Out:
# Mounted at /content/gdrive
# El dataset se encuentra descargado en el directorio /content/gdrive/My Drive/dwld_dir
# y descomprimido en el directorio /content/work_dir (usado para lectura de datos)

# %%
import tensorflow.keras.layers as layers
import tensorflow.keras.models as models
import tensorflow as tf
import pathlib
import numpy as np

dataset_dir = pathlib.Path(work_dir + '/scenes15/')

# Obtener etiquetas de clase y numero de clases
CLASS_NAMES = np.array([item.name for item in dataset_dir.glob('*')]) #clases son subdirectorios de '/train/'
NUM_CLASSES = len(CLASS_NAMES) # numero total de clases

# Crear ImageDataGenerator convirtiendo de uint8 a float32 en el rango [0,1].
img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.20)

# rendimiento
acc = []
val_acc = []

loss = []
val_loss = []

batch_sizes = [8, 16, 32, 64]
for batch_size in batch_sizes:
  # Obtenemos un iterador sobre los datos de entrenamiento del dataset
  # aplicando el ImageDataGenerator creado anteriormente
  BATCH_SIZE = batch_size # numero de elementos procesados conjuntamente en cada iteracion
  IMG_HEIGHT = 32
  IMG_WIDTH = 32
  IMG_CHANNELS = 3
  train_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE,
                                            subset="training",
                                            shuffle=True,
                                            seed=0)

  test_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE,
                                            subset="validation",
                                            shuffle=True,
                                            seed=0)
  # definir modelo de red
  model = models.Sequential()

  # incluir capa convolucional C1
  model.add(layers.Conv2D(filters=6,
                          kernel_size=(3, 3),
                          strides = (1,1),
                          padding = 'valid',
                          activation='relu',
                          input_shape=(IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)))

  # incluir average pooling S2
  model.add(layers.AveragePooling2D())

  # incluir capa convolucional C3
  model.add(layers.Conv2D(filters=16,
                          kernel_size=(3, 3),
                          strides = (1,1),
                          padding = 'valid',
                          activation='relu'))

  # incluir average pooling S4
  model.add(layers.AveragePooling2D())

  # convertir el volumen de datos en vector fila para conectarlo con capa FC
  model.add(layers.Flatten())

  # incluir fully convolutional F5
  model.add(layers.Dense(units=120, activation='relu'))

  # incluir fully convolutional F6
  model.add(layers.Dense(units=84, activation='relu'))

  # incluir salida OUTPUT
  model.add(layers.Dense(units=NUM_CLASSES, activation = 'softmax'))


  # mostar resumen
  model.summary()

  import tensorflow.keras.optimizers as optimizers

  # definicion con optimizador con valores definidos por el usuario
  LEARNING_RATE = 0.01 # factor de aprendizaje
  model.compile(optimizer=optimizers.SGD(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
  import time
  stime = time.time() # medida inicial de tiempo

  EPOCHS = 50 # numero de epocas para entrenamiento

  #si tiene problemas al ejecutar con la GPU,
  # descomente la siguiente linea para utilizar la CPU
  # y comente la linea que selecciona la GPU
  #with tf.device('/CPU:0'):
  with tf.device('/GPU:0'):
    history = model.fit_generator(
        generator=train_data_gen,
        steps_per_epoch=train_data_gen.n // BATCH_SIZE,
        validation_data=test_data_gen,
        validation_steps=test_data_gen.n // BATCH_SIZE,
        epochs=EPOCHS,
        verbose=1
    )

  ftime = time.time() # medida final de tiempo
  print('Entrenamiento terminado {} secs' .format(ftime-stime))

  import time
  stime = time.time() # medida inicial de tiempo

  #si tiene problemas al ejecutar con la GPU,
  # descomente la siguiente linea para utilizar la CPU
  # y comente la linea que selecciona la GPU
  #with tf.device('/CPU:0'):
  with tf.device('/GPU:0'):
    test_loss, test_acc = model.evaluate_generator(generator=test_data_gen,
                                                  steps = test_data_gen.n // BATCH_SIZE,
                                                  verbose=1)

  ftime = time.time() # medida final de tiempo
  print('Test terminado {} secs' .format(ftime-stime))
  # rendimiento
  acc.append(history.history['accuracy'])         #entrenamiento
  val_acc.append(history.history['val_accuracy']) #validacion

  # funcion de perdidas
  loss.append(history.history['loss'])            #entrenamiento
  val_loss.append(history.history['val_loss'])    #validacion

import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))

def show_results(title, items):
  for i in range(len(batch_sizes)):
    plt.plot(range(EPOCHS), items[i], label=f'batch size = {batch_sizes[i]}')

  plt.legend(loc='upper left')
  plt.xlabel('# epoca')
  plt.title(title)
  plt.show()


show_results("Rendimiento train (accuracy)", acc)
show_results("Rendimiento test (accuracy)", val_acc)
show_results("Pérdidas train (loss)", loss)
show_results("Pérdidas test (loss)", val_loss)
# Out:
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_34 (Conv2D)          (None, 30, 30, 6)         168
#
#  average_pooling2d_34 (Avera  (None, 15, 15, 6)        0
#  gePooling2D)
#
#  conv2d_35 (Conv2D)          (None, 13, 13, 16)        880
#
#  average_pooling2d_35 (Avera  (None, 6, 6, 16)         0
#  gePooling2D)
#
#  flatten_17 (Flatten)        (None, 576)               0
#
#  dense_51 (Dense)            (None, 120)               69240
#
#  dense_52 (Dense)            (None, 84)                10164
#
#  dense_53 (Dense)            (None, 15)                1275
#
# =================================================================
# Total params: 81,727
# Trainable params: 81,727
# Non-trainable params: 0
# _________________________________________________________________
# <ipython-input-9-908c3deae0dd>:107: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1
50
# 449/449 [==============================] - 7s 16ms/step - loss: 0.1311 - accuracy: 0.9630 - val_loss: 4.0401 - val_accuracy: 0.3750
# Epoch 45/50
# 449/449 [==============================] - 8s 17ms/step - loss: 0.1020 - accuracy: 0.9724 - val_loss: 3.9342 - val_accuracy: 0.3964
# Epoch 46/50
# 449/449 [==============================] - 11s 25ms/step - loss: 0.0821 - accuracy: 0.9780 - val_loss: 4.2050 - val_accuracy: 0.3829
# Epoch 47/50
# 449/449 [==============================] - 7s 16ms/step - loss: 0.1277 - accuracy: 0.9605 - val_loss: 4.5525 - val_accuracy: 0.3784
# Epoch 48/50
# 449/449 [==============================] - 8s 17ms/step - loss: 0.1594 - accuracy: 0.9555 - val_loss: 4.2752 - val_accuracy: 0.3885
# Epoch 49/50
# 449/449 [==============================] - 7s 16ms/step - loss: 0.0934 - accuracy: 0.9738 - val_loss: 4.4054 - val_accuracy: 0.3761
# Epoch 50/50
# 449/449 [==============================] - 7s 15ms/step - loss: 0.0636 - accuracy: 0.9858 - val_loss: 4.2464 - val_accuracy: 0.3953
# Entrenamiento terminado 391.8245379924774 secs
#  15/111 [===>..........................] - ETA: 0s - loss: 4.1672 - accuracy: 0.3833
# <ipython-input-9-908c3deae0dd>:127: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_acc = model.evaluate_generator(generator=test_data_gen,
# 111/111 [==============================] - 1s 8ms/step - loss: 4.2403 - accuracy: 0.3975
# Test terminado 0.9404869079589844 secs
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 30, 30, 6)         168
#
#  average_pooling2d_36 (Avera  (None, 15, 15, 6)        0
#  gePooling2D)
#
#  conv2d_37 (Conv2D)          (None, 13, 13, 16)        880
#
#  average_pooling2d_37 (Avera  (None, 6, 6, 16)         0
#  gePooling2D)
#
#  flatten_18 (Flatten)        (None, 576)               0
#
#  dense_54 (Dense)            (None, 120)               69240
#
#  dense_55 (Dense)            (None, 84)                10164
#
#  dense_56 (Dense)            (None, 15)                1275
#
# =================================================================
# Total params: 81,727
# Trainable params: 81,727
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# <ipython-input-9-908c3deae0dd>:107: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 224/224 [==============================] - 8s 34ms/step - loss: 2.6907 - accuracy: 0.0945 - val_loss: 2.6766 - val_accuracy: 0.0795
# Epoch 2/50
# 224/224 [==============================] - 8s 37ms/step - loss: 2.6571 - accuracy: 0.1133 - val_loss: 2.6504 - val_accuracy: 0.0909
# Epoch 3/50
# 224/224 [==============================] - 7s 32ms/step - loss: 2.5973 - accuracy: 0.1449 - val_loss: 2.5987 - val_accuracy: 0.1227
# Epoch 4/50
# 224/224 [==============================] - 7s 31ms/step - loss: 2.5360 - accuracy: 0.1619 - val_loss: 2.5729 - val_accuracy: 0.1398
# Epoch 5/50
# 224/224 [==============================] - 7s 31ms/step - loss: 2.4903 - accuracy: 0.1793 - val_loss: 2.5232 - val_accuracy: 0.1761
# Epoch 6/50
# 224/224 [==============================] - 6s 28ms/step - loss: 2.4533 - accuracy: 0.1980 - val_loss: 2.5338 - val_accuracy: 0.1580
# Epoch 7/50
# 224/224 [==============================] - 6s 28ms/step - loss: 2.4121 - accuracy: 0.2053 - val_loss: 2.4817 - val_accuracy: 0.2091
# Epoch 8/50
# 224/224 [==============================] - 5s 23ms/step - loss: 2.3749 - accuracy: 0.2304 - val_loss: 2.4845 - val_accuracy: 0.1989
# Epoch 9/50
# 224/224 [==============================] - 7s 33ms/step - loss: 0.7739 - accuracy: 0.7352 - val_loss: 2.8119 - val_accuracy: 0.3023
# Epoch 48/50
# 224/224 [==============================] - 5s 21ms/step - loss: 0.7447 - accuracy: 0.7469 - val_loss: 2.8726 - val_accuracy: 0.3125
# Epoch 49/50
# 224/224 [==============================] - 8s 36ms/step - loss: 0.7042 - accuracy: 0.7659 - val_loss: 2.7512 - val_accuracy: 0.3432
# Epoch 50/50
# 224/224 [==============================] - 8s 36ms/step - loss: 0.6365 - accuracy: 0.7830 - val_loss: 2.7583 - val_accuracy: 0.3352
# Entrenamiento terminado 360.72000455856323 secs
#  5/55 [=>............................] - ETA: 0s - loss: 2.2219 - accuracy: 0.4500
# <ipython-input-9-908c3deae0dd>:127: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_acc = model.evaluate_generator(generator=test_data_gen,
# 55/55 [==============================] - 1s 14ms/step - loss: 2.7661 - accuracy: 0.3352
# Test terminado 0.8724792003631592 secs
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_38 (Conv2D)          (None, 30, 30, 6)         168
#
#  average_pooling2d_38 (Avera  (None, 15, 15, 6)        0
#  gePooling2D)
#
#  conv2d_39 (Conv2D)          (None, 13, 13, 16)        880
#
#  average_pooling2d_39 (Avera  (None, 6, 6, 16)         0
#  gePooling2D)
#
#  flatten_19 (Flatten)        (None, 576)               0
#
#  dense_57 (Dense)            (None, 120)               69240
#
#  dense_58 (Dense)            (None, 84)                10164
#
#  dense_59 (Dense)            (None, 15)                1275
#
# =================================================================
# Total params: 81,727
# Trainable params: 81,727
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# <ipython-input-9-908c3deae0dd>:107: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 112/112 [==============================] - 8s 65ms/step - loss: 2.7045 - accuracy: 0.0834 - val_loss: 2.6999 - val_accuracy: 0.1192
# Epoch 2/50
# 112/112 [==============================] - 7s 63ms/step - loss: 2.6960 - accuracy: 0.0986 - val_loss: 2.6925 - val_accuracy: 0.1169
# Epoch 3/50
# 112/112 [==============================] - 6s 57ms/step - loss: 2.6878 - accuracy: 0.1037 - val_loss: 2.6843 - val_accuracy: 0.1019
# Epoch 4/50
# 112/112 [==============================] - 6s 56ms/step - loss: 2.6767 - accuracy: 0.1022 - val_loss: 2.6757 - val_accuracy: 0.0995
# Epoch 5/50
# 112/112 [==============================] - 6s 57ms/step - loss: 2.6611 - accuracy: 0.1104 - val_loss: 2.6602 - val_accuracy: 0.0926
# Epoch 6/50
# 112/112 [==============================] - 6s 52ms/step - loss: 2.6363 - accuracy: 0.1107 - val_loss: 2.6429 - val_accuracy: 0.1273
# Epoch 7/50
# 112/112 [==============================] - 6s 56ms/step - loss: 2.5986 - accuracy: 0.1348 - val_loss: 2.6388 - val_accuracy: 0.1319
# Epoch 8/50
# 112/112 [==============================] - 6s 53ms/step - loss: 2.5578 - accuracy: 0.1508 - val_loss: 2.6119 - val_accuracy: 0.1088
# Epoch 9/50
# 112/112 [==============================] - 6s 50ms/step - loss: 2.5238 - accuracy: 0.1666 - val_loss: 2.5703 - val_accuracy: 0.1667
# Epoch 10/50
# 112/112 [==============================] - 7s 64ms/step - loss: 2.4907 - accuracy: 0.1851 - val_loss: 2.5515 - val_accuracy: 0.1539
# Epoch 11/50
# 112/112 [==============================] - 7s 59ms/step - loss: 2.4577 - accuracy: 0.1952 - val_loss: 2.5128 - val_accuracy: 0.1782
# Epoch 12/50
# 112/112 [==============================] - 8s 70ms/step - loss: 2.4362 - accuracy: 0.2062 - val_loss: 2.4948 - val_accuracy: 0.1956
# Epoch 13/50
# 112/112 [==============================] - 6s 58ms/step - loss: 2.4153 - accuracy: 0.2140 - val_loss: 2.4836 - val_accuracy: 0.2060
# Epoch 14/50
# 112/112 [==============================] - 7s 59ms/step - loss: 2.3859 - accuracy: 0.2360 - val_loss: 2.4684 - val_accuracy: 0.2083
# Epoch 15/50
# 112/112 [==============================] - 6s 52ms/step - loss: 2.3607 - accuracy: 0.2312 - val_loss: 2.4418 - val_accuracy: 0.2002
# Epoch 16/50
# 112/112 [==============================] - 7s 64ms/step - loss: 2.3328 - accuracy: 0.2494 - val_loss: 2.5504 - val_accuracy: 0.1852
# Epoch 17/50
# 112/112 [==============================] - 7s 65ms/step - loss: 2.2988 - accuracy: 0.2486 - val_loss: 2.4115 - val_accuracy: 0.2269
# Epoch 18/50
# 112/112 [==============================] - 9s 77ms/step - loss: 2.2695 - accuracy: 0.2669 - val_loss: 2.3841 - val_accuracy: 0.2407
# Epoch 19/50
# 112/112 [==============================] - 7s 67ms/step - loss: 2.2394 - accuracy: 0.2674 - val_loss: 2.3628 - val_accuracy: 0.2396
# Epoch 20/50
# 112/112 [==============================] - 6s 52ms/step - loss: 2.2075 - accuracy: 0.2789 - val_loss: 2.3094 - val_accuracy: 0.2512
# Epoch 21/50
# 112/112 [==============================] - 5s 47ms/step - loss: 2.1666 - accuracy: 0.2896 - val_loss: 2.4021 - val_accuracy: 0.2303
# Epoch 22/50
# 112/112 [==============================] - 8s 69ms/step - loss: 2.1302 - accuracy: 0.2994 - val_loss: 2.2696 - val_accuracy: 0.2616
# Epoch 23/50
# 112/112 [==============================] - 7s 63ms/step - loss: 2.0975 - accuracy: 0.3062 - val_loss: 2.2179 - val_accuracy: 0.2604
# Epoch 24/50
# 112/112 [==============================] - 8s 70ms/step - loss: 2.0544 - accuracy: 0.3132 - val_loss: 2.2041 - val_accuracy: 0.3113
# Epoch 25/50
# 112/112 [==============================] - 6s 54ms/step - loss: 2.0294 - accuracy: 0.3275 - val_loss: 2.1799 - val_accuracy: 0.2894
# Epoch 26/50
# 112/112 [==============================] - 8s 71ms/step - loss: 1.9856 - accuracy: 0.3326 - val_loss: 2.2163 - val_accuracy: 0.2801
# Epoch 27/50
# 112/112 [==============================] - 6s 57ms/step - loss: 1.9698 - accuracy: 0.3469 - val_loss: 2.1083 - val_accuracy: 0.2986
# Epoch 28/50
# 112/112 [==============================] - 8s 73ms/step - loss: 1.9378 - accuracy: 0.3553 - val_loss: 2.2538 - val_accuracy: 0.2477
# Epoch 29/50
# 112/112 [==============================] - 8s 71ms/step - loss: 1.9064 - accuracy: 0.3643 - val_loss: 2.2356 - val_accuracy: 0.2720
# Epoch 30/50
# 112/112 [==============================] - 6s 53ms/step - loss: 1.9015 - accuracy: 0.3657 - val_loss: 2.1473 - val_accuracy: 0.2940
# Epoch 31/50
# 112/112 [==============================] - 6s 51ms/step - loss: 1.8685 - accuracy: 0.3713 - val_loss: 2.0952 - val_accuracy: 0.3113
# Epoch 32/50
# 112/112 [==============================] - 6s 58ms/step - loss: 1.8491 - accuracy: 0.3770 - val_loss: 2.0469 - val_accuracy: 0.3137
# Epoch 33/50
# 112/112 [==============================] - 7s 60ms/step - loss: 1.8334 - accuracy: 0.3893 - val_loss: 2.0276 - val_accuracy: 0.3171
# Epoch 34/50
# 112/112 [==============================] - 7s 62ms/step - loss: 1.8186 - accuracy: 0.3989 - val_loss: 2.0103 - val_accuracy: 0.3310
# Epoch 35/50
# 112/112 [==============================] - 7s 58ms/step - loss: 1.7808 - accuracy: 0.4084 - val_loss: 2.0482 - val_accuracy: 0.3125
# Epoch 36/50
# 112/112 [==============================] - 7s 63ms/step - loss: 1.7532 - accuracy: 0.4225 - val_loss: 2.0862 - val_accuracy: 0.3009
# Epoch 37/50
# 112/112 [==============================] - 8s 70ms/step - loss: 1.7507 - accuracy: 0.4264 - val_loss: 2.1337 - val_accuracy: 0.3160
# Epoch 38/50
# 112/112 [==============================] - 8s 69ms/step - loss: 1.7231 - accuracy: 0.4309 - val_loss: 2.0489 - val_accuracy: 0.3160
# Epoch 39/50
# 112/112 [==============================] - 7s 61ms/step - loss: 1.6830 - accuracy: 0.4410 - val_loss: 2.2419 - val_accuracy: 0.2766
# Epoch 40/50
# 112/112 [==============================] - 9s 82ms/step - loss: 1.6748 - accuracy: 0.4421 - val_loss: 2.0069 - val_accuracy: 0.3275
# Epoch 41/50
# 112/112 [==============================] - 8s 71ms/step - loss: 1.6517 - accuracy: 0.4534 - val_loss: 1.9433 - val_accuracy: 0.3472
# Epoch 42/50
# 112/112 [==============================] - 7s 66ms/step - loss: 1.6302 - accuracy: 0.4590 - val_loss: 1.9972 - val_accuracy: 0.3345
# Epoch 43/50
# 112/112 [==============================] - 7s 63ms/step - loss: 1.6064 - accuracy: 0.4626 - val_loss: 1.9917 - val_accuracy: 0.3125
# Epoch 44/50
# 112/112 [==============================] - 5s 49ms/step - loss: 1.5788 - accuracy: 0.4775 - val_loss: 1.9199 - val_accuracy: 0.3507
# Epoch 45/50
# 112/112 [==============================] - 6s 57ms/step - loss: 1.5517 - accuracy: 0.4854 - val_loss: 1.9458 - val_accuracy: 0.3611
# Epoch 46/50
# 112/112 [==============================] - 5s 44ms/step - loss: 1.5499 - accuracy: 0.4871 - val_loss: 1.9624 - val_accuracy: 0.3438
# Epoch 47/50
# 112/112 [==============================] - 9s 76ms/step - loss: 1.5184 - accuracy: 0.4933 - val_loss: 1.9709 - val_accuracy: 0.3356
# Epoch 48/50
# 112/112 [==============================] - 6s 51ms/step - loss: 1.4980 - accuracy: 0.5070 - val_loss: 1.9930 - val_accuracy: 0.3322
# Epoch 49/50
# 112/112 [==============================] - 7s 64ms/step - loss: 1.4568 - accuracy: 0.5171 - val_loss: 1.9256 - val_accuracy: 0.3727
# Epoch 50/50
# 112/112 [==============================] - 9s 79ms/step - loss: 1.4406 - accuracy: 0.5284 - val_loss: 1.9460 - val_accuracy: 0.3495
# Entrenamiento terminado 352.0609927177429 secs
#  3/27 [==>...........................] - ETA: 0s - loss: 1.8668 - accuracy: 0.4375
# <ipython-input-9-908c3deae0dd>:127: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_acc = model.evaluate_generator(generator=test_data_gen,
# 27/27 [==============================] - 2s 77ms/step - loss: 1.9435 - accuracy: 0.3519
# Test terminado 2.1340630054473877 secs
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 30, 30, 6)         168
#
#  average_pooling2d_40 (Avera  (None, 15, 15, 6)        0
#  gePooling2D)
#
#  conv2d_41 (Conv2D)          (None, 13, 13, 16)        880
#
#  average_pooling2d_41 (Avera  (None, 6, 6, 16)         0
#  gePooling2D)
#
#  flatten_20 (Flatten)        (None, 576)               0
#
#  dense_60 (Dense)            (None, 120)               69240
#
#  dense_61 (Dense)            (None, 84)                10164
#
#  dense_62 (Dense)            (None, 15)                1275
#
# =================================================================
# Total params: 81,727
# Trainable params: 81,727
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# <ipython-input-9-908c3deae0dd>:107: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 56/56 [==============================] - 8s 140ms/step - loss: 2.7041 - accuracy: 0.0785 - val_loss: 2.6981 - val_accuracy: 0.0889
# Epoch 2/50
# 56/56 [==============================] - 7s 129ms/step - loss: 2.6971 - accuracy: 0.0941 - val_loss: 2.6922 - val_accuracy: 0.0913
# Epoch 3/50
# 56/56 [==============================] - 7s 125ms/step - loss: 2.6917 - accuracy: 0.0930 - val_loss: 2.6869 - val_accuracy: 0.0901
# Epoch 4/50
# 56/56 [==============================] - 6s 106ms/step - loss: 2.6866 - accuracy: 0.0916 - val_loss: 2.6839 - val_accuracy: 0.0913
# Epoch 5/50
# 56/56 [==============================] - 6s 110ms/step - loss: 2.6806 - accuracy: 0.0921 - val_loss: 2.6791 - val_accuracy: 0.0889
# Epoch 6/50
# 56/56 [==============================] - 6s 107ms/step - loss: 2.6740 - accuracy: 0.0930 - val_loss: 2.6748 - val_accuracy: 0.0913
# Epoch 7/50
# 56/56 [==============================] - 6s 108ms/step - loss: 2.6659 - accuracy: 0.0927 - val_loss: 2.6700 - val_accuracy: 0.0925
# Epoch 8/50
# 56/56 [==============================] - 7s 120ms/step - loss: 2.6554 - accuracy: 0.0955 - val_loss: 2.6590 - val_accuracy: 0.1034
# Epoch 9/50
# 56/56 [==============================] - 5s 86ms/step - loss: 2.6405 - accuracy: 0.1046 - val_loss: 2.6481 - val_accuracy: 0.1034
# Epoch 10/50
# 56/56 [==============================] - 7s 132ms/step - loss: 2.6186 - accuracy: 0.1293 - val_loss: 2.6246 - val_accuracy: 0.0986
# Epoch 11/50
# 56/56 [==============================] - 6s 100ms/step - loss: 2.5909 - accuracy: 0.1460 - val_loss: 2.6061 - val_accuracy: 0.1430
# Epoch 12/50
# 56/56 [==============================] - 7s 122ms/step - loss: 2.5587 - accuracy: 0.1519 - val_loss: 2.5810 - val_accuracy: 0.1394
# Epoch 13/50
# 56/56 [==============================] - 6s 101ms/step - loss: 2.5332 - accuracy: 0.1652 - val_loss: 2.5788 - val_accuracy: 0.1322
# Epoch 14/50
# 56/56 [==============================] - 5s 97ms/step - loss: 2.5085 - accuracy: 0.1723 - val_loss: 2.5767 - val_accuracy: 0.1250
# Epoch 15/50
# 56/56 [==============================] - 7s 122ms/step - loss: 2.4953 - accuracy: 0.1814 - val_loss: 2.5579 - val_accuracy: 0.1526
# Epoch 16/50
# 56/56 [==============================] - 7s 129ms/step - loss: 2.4816 - accuracy: 0.1811 - val_loss: 2.5322 - val_accuracy: 0.1611
# Epoch 17/50
# 56/56 [==============================] - 7s 123ms/step - loss: 2.4637 - accuracy: 0.1933 - val_loss: 2.5249 - val_accuracy: 0.1779
# Epoch 18/50
# 56/56 [==============================] - 5s 87ms/step - loss: 2.4536 - accuracy: 0.1908 - val_loss: 2.5132 - val_accuracy: 0.1767
# Epoch 19/50
# 56/56 [==============================] - 6s 116ms/step - loss: 2.4396 - accuracy: 0.2046 - val_loss: 2.5108 - val_accuracy: 0.1743
# Epoch 20/50
# 56/56 [==============================] - 5s 98ms/step - loss: 2.4302 - accuracy: 0.2095 - val_loss: 2.5023 - val_accuracy: 0.1887
# Epoch 21/50
# 56/56 [==============================] - 7s 132ms/step - loss: 2.4147 - accuracy: 0.2100 - val_loss: 2.4956 - val_accuracy: 0.1803
# Epoch 22/50
# 56/56 [==============================] - 7s 124ms/step - loss: 2.4029 - accuracy: 0.2112 - val_loss: 2.4849 - val_accuracy: 0.1899
# Epoch 23/50
# 56/56 [==============================] - 4s 74ms/step - loss: 2.3947 - accuracy: 0.2106 - val_loss: 2.4926 - val_accuracy: 0.1923
# Epoch 24/50
# 56/56 [==============================] - 5s 91ms/step - loss: 2.3813 - accuracy: 0.2285 - val_loss: 2.4958 - val_accuracy: 0.1923
# Epoch 25/50
# 56/56 [==============================] - 7s 120ms/step - loss: 2.3712 - accuracy: 0.2251 - val_loss: 2.4735 - val_accuracy: 0.2067
# Epoch 26/50
# 56/56 [==============================] - 6s 107ms/step - loss: 2.3526 - accuracy: 0.2241 - val_loss: 2.4575 - val_accuracy: 0.2127
# Epoch 27/50
# 56/56 [==============================] - 7s 118ms/step - loss: 2.3501 - accuracy: 0.2364 - val_loss: 2.4479 - val_accuracy: 0.2067
# Epoch 28/50
# 56/56 [==============================] - 5s 98ms/step - loss: 2.3192 - accuracy: 0.2443 - val_loss: 2.4729 - val_accuracy: 0.2007
# Epoch 29/50
# 56/56 [==============================] - 5s 88ms/step - loss: 2.3087 - accuracy: 0.2537 - val_loss: 2.4594 - val_accuracy: 0.1971
# Epoch 30/50
# 56/56 [==============================] - 7s 125ms/step - loss: 2.2972 - accuracy: 0.2449 - val_loss: 2.4467 - val_accuracy: 0.2212
# Epoch 31/50
# 56/56 [==============================] - 6s 111ms/step - loss: 2.2900 - accuracy: 0.2520 - val_loss: 2.4176 - val_accuracy: 0.2368
# Epoch 32/50
# 56/56 [==============================] - 6s 101ms/step - loss: 2.2698 - accuracy: 0.2619 - val_loss: 2.4049 - val_accuracy: 0.2200
# Epoch 33/50
# 56/56 [==============================] - 5s 98ms/step - loss: 2.2682 - accuracy: 0.2526 - val_loss: 2.3929 - val_accuracy: 0.2284
# Epoch 34/50
# 56/56 [==============================] - 5s 87ms/step - loss: 2.2435 - accuracy: 0.2730 - val_loss: 2.3683 - val_accuracy: 0.2308
# Epoch 35/50
# 56/56 [==============================] - 5s 88ms/step - loss: 2.2220 - accuracy: 0.2795 - val_loss: 2.4005 - val_accuracy: 0.2236
# Epoch 36/50
# 56/56 [==============================] - 6s 110ms/step - loss: 2.2146 - accuracy: 0.2713 - val_loss: 2.3674 - val_accuracy: 0.2224
# Epoch 37/50
# 56/56 [==============================] - 7s 117ms/step - loss: 2.2090 - accuracy: 0.2786 - val_loss: 2.3451 - val_accuracy: 0.2380
# Epoch 38/50
# 56/56 [==============================] - 7s 120ms/step - loss: 2.1872 - accuracy: 0.2866 - val_loss: 2.3380 - val_accuracy: 0.2488
# Epoch 39/50
# 56/56 [==============================] - 5s 90ms/step - loss: 2.1597 - accuracy: 0.2976 - val_loss: 2.3204 - val_accuracy: 0.2464
# Epoch 40/50
# 56/56 [==============================] - 6s 100ms/step - loss: 2.1617 - accuracy: 0.2988 - val_loss: 2.3652 - val_accuracy: 0.2188
# Epoch 41/50
# 56/56 [==============================] - 6s 111ms/step - loss: 2.1386 - accuracy: 0.3070 - val_loss: 2.3167 - val_accuracy: 0.2368
# Epoch 42/50
# 56/56 [==============================] - 7s 132ms/step - loss: 2.1027 - accuracy: 0.3109 - val_loss: 2.2866 - val_accuracy: 0.2608
# Epoch 43/50
# 56/56 [==============================] - 6s 102ms/step - loss: 2.1010 - accuracy: 0.3124 - val_loss: 2.3036 - val_accuracy: 0.2488
# Epoch 44/50
# 56/56 [==============================] - 5s 93ms/step - loss: 2.0818 - accuracy: 0.3214 - val_loss: 2.2935 - val_accuracy: 0.2440
# Epoch 45/50
# 56/56 [==============================] - 7s 118ms/step - loss: 2.0755 - accuracy: 0.3209 - val_loss: 2.2484 - val_accuracy: 0.2656
# Epoch 46/50
# 56/56 [==============================] - 6s 103ms/step - loss: 2.0403 - accuracy: 0.3362 - val_loss: 2.2390 - val_accuracy: 0.2632
# Epoch 47/50
# 56/56 [==============================] - 7s 133ms/step - loss: 2.0099 - accuracy: 0.3427 - val_loss: 2.2723 - val_accuracy: 0.2632
# Epoch 48/50
# 56/56 [==============================] - 7s 128ms/step - loss: 2.0038 - accuracy: 0.3464 - val_loss: 2.1965 - val_accuracy: 0.2644
# Epoch 49/50
# 56/56 [==============================] - 7s 118ms/step - loss: 1.9988 - accuracy: 0.3520 - val_loss: 2.2186 - val_accuracy: 0.2764
# Epoch 50/50
# 56/56 [==============================] - 6s 109ms/step - loss: 1.9716 - accuracy: 0.3512 - val_loss: 2.2223 - val_accuracy: 0.2861
# Entrenamiento terminado 314.98923778533936 secs
#  1/13 [=>............................] - ETA: 1s - loss: 2.2283 - accuracy: 0.2188
# <ipython-input-9-908c3deae0dd>:127: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_acc = model.evaluate_generator(generator=test_data_gen,
# 13/13 [==============================] - 2s 122ms/step - loss: 2.2212 - accuracy: 0.2849
# Test terminado 1.686518907546997 secs
