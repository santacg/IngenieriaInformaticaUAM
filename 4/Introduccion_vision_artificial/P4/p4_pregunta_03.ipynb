# %%
#%%capture
#%tensorflow_version 2.x
# !pip install tensorflow==2.9.2
# Out:
# Requirement already satisfied: tensorflow==2.9.2 in /usr/local/lib/python3.10/dist-packages (2.9.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.6.3)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.12)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.68.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (3.12.1)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (2.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (24.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (3.19.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.17.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (2.9.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (0.37.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (2.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.2) (1.17.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.9.2) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2) (3.2.2)

# %%
import tensorflow as tf
# !python --version                     # mostrar version de python
print('Tensorflow ' + tf.__version__) # mostrar version tensorflow
# Out:
# Python 3.10.12
# Tensorflow 2.9.2

# %%
import os, subprocess

# Montar Google Drive y crear carpetas
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

work_dir = '/content/work_dir'                    # directorio de trabajo en local (mas rapido)
dwld_dir = '/content/gdrive/My Drive/dwld_dir'    # directorio de descarga en Google drive personal
subprocess.call(["mkdir","-p",work_dir])          # crear directorio para trabajo
subprocess.call(["mkdir","-p",dwld_dir+'/dataset/'])  # crear directorio para dataset

os.chdir(dwld_dir+'/dataset/')                        # posicionarse en el directorio
# Descargar dataset scenes15 si no esta disponible
if os.path.isfile('./dataset_scenes15.zip') == False:
  # !wget http://www-vpu.eps.uam.es/~jcs/tsv/dataset_scenes15.zip

# Copiar el dataset al directorio local (mayor velocidad de lectura que en Gdrive)
# !cp /content/gdrive/My\ Drive/dwld_dir/dataset/dataset_scenes15.zip /content/work_dir/

os.chdir(work_dir)                        # posicionarse en el directorio
if os.path.isdir('./scenes15') == False:
  # !unzip -o -q dataset_scenes15.zip -d .

print('El dataset se encuentra descargado en el directorio {} \ny descomprimido en el directorio {} (usado para lectura de datos)'.format(dwld_dir, work_dir))
# Out:
# Mounted at /content/gdrive
# El dataset se encuentra descargado en el directorio /content/gdrive/My Drive/dwld_dir
# y descomprimido en el directorio /content/work_dir (usado para lectura de datos)

# %%
import tensorflow.keras.layers as layers
import tensorflow.keras.models as models
import tensorflow as tf
import pathlib
import numpy as np

dataset_dir = pathlib.Path(work_dir + '/scenes15/')

# Obtener etiquetas de clase y numero de clases
CLASS_NAMES = np.array([item.name for item in dataset_dir.glob('*')]) #clases son subdirectorios de '/train/'
NUM_CLASSES = len(CLASS_NAMES) # numero total de clases

# Crear ImageDataGenerator convirtiendo de uint8 a float32 en el rango [0,1].
img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.20)

acc = []
val_acc = []

loss = []
val_loss = []

fns_activacion = ['relu', 'sigmoid', 'tanh', 'leaky_relu']

for fn_activacion in fns_activacion:
  # Obtenemos un iterador sobre los datos de entrenamiento del dataset
  # aplicando el ImageDataGenerator creado anteriormente
  BATCH_SIZE = 32 # numero de elementos procesados conjuntamente en cada iteracion
  IMG_HEIGHT = 64
  IMG_WIDTH = 64
  IMG_CHANNELS = 3
  train_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE,
                                            subset="training",
                                            shuffle=True,
                                            seed=0)

  test_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE,
                                            subset="validation",
                                            shuffle=True,
                                            seed=0)
  # definir modelo de red
  model = models.Sequential()

  # incluir capa convolucional C1
  model.add(layers.Conv2D(filters=6,
                          kernel_size=(3, 3),
                          strides = (1,1),
                          padding = 'valid',
                          activation=fn_activacion,
                          input_shape=(IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)))

  # incluir average pooling S2
  model.add(layers.AveragePooling2D())

  # incluir capa convolucional C3
  model.add(layers.Conv2D(filters=16,
                          kernel_size=(3, 3),
                          strides = (1,1),
                          padding = 'valid',
                          activation=fn_activacion))

  # incluir average pooling S4
  model.add(layers.AveragePooling2D())

  # convertir el volumen de datos en vector fila para conectarlo con capa FC
  model.add(layers.Flatten())

  # incluir fully convolutional F5
  model.add(layers.Dense(units=120, activation=fn_activacion))

  # incluir fully convolutional F6
  model.add(layers.Dense(units=84, activation=fn_activacion))

  # incluir salida OUTPUT
  model.add(layers.Dense(units=NUM_CLASSES, activation = 'softmax'))


  # mostar resumen
  model.summary()

  import tensorflow.keras.optimizers as optimizers

  # definicion con optimizador con valores definidos por el usuario
  LEARNING_RATE = 0.01 # factor de aprendizaje
  model.compile(optimizer=optimizers.SGD(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
  import time
  stime = time.time() # medida inicial de tiempo

  EPOCHS = 25 # numero de epocas para entrenamiento

  #si tiene problemas al ejecutar con la GPU,
  # descomente la siguiente linea para utilizar la CPU
  # y comente la linea que selecciona la GPU
  #with tf.device('/CPU:0'):
  with tf.device('/GPU:0'):
    history = model.fit_generator(
        generator=train_data_gen,
        steps_per_epoch=train_data_gen.n // BATCH_SIZE,
        validation_data=test_data_gen,
        validation_steps=test_data_gen.n // BATCH_SIZE,
        epochs=EPOCHS,
        verbose=1
    )

  ftime = time.time() # medida final de tiempo
  print('Entrenamiento terminado {} secs' .format(ftime-stime))

  import time
  stime = time.time() # medida inicial de tiempo

  #si tiene problemas al ejecutar con la GPU,
  # descomente la siguiente linea para utilizar la CPU
  # y comente la linea que selecciona la GPU
  #with tf.device('/CPU:0'):
  with tf.device('/GPU:0'):
    test_loss, test_acc = model.evaluate_generator(generator=test_data_gen,
                                                  steps = test_data_gen.n // BATCH_SIZE,
                                                  verbose=1)

  ftime = time.time() # medida final de tiempo
  print('Test terminado {} secs' .format(ftime-stime))

  # rendimiento
  acc.append(history.history['accuracy'])         #entrenamiento
  val_acc.append(history.history['val_accuracy']) #validacion

  # funcion de perdidas
  loss.append(history.history['loss'])            #entrenamiento
  val_loss.append(history.history['val_loss'])    #validacion

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))

def show_results(title, items):
  for i in range(len(fns_activacion)):
    plt.plot(range(EPOCHS), items[i], label=f'Función de activación: {fns_activacion[i]}')

  plt.legend(loc='upper left')
  plt.xlabel('# epoca')
  plt.title(title)
  plt.show()


show_results("Rendimiento train (accuracy)", acc)
show_results("Rendimiento test (accuracy)", val_acc)
show_results("Pérdidas train (loss)", loss)
show_results("Pérdidas test (loss)", val_loss)
# Out:
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 62, 62, 6)         168
#
#  average_pooling2d_10 (Avera  (None, 31, 31, 6)        0
#  gePooling2D)
#
#  conv2d_11 (Conv2D)          (None, 29, 29, 16)        880
#
#  average_pooling2d_11 (Avera  (None, 14, 14, 16)       0
#  gePooling2D)
#
#  flatten_5 (Flatten)         (None, 3136)              0
#
#  dense_15 (Dense)            (None, 120)               376440
#
#  dense_16 (Dense)            (None, 84)                10164
#
#  dense_17 (Dense)            (None, 15)                1275
#
# =================================================================
# Total params: 388,927
# Trainable params: 388,927
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# <ipython-input-6-6ac806f691b4>:107: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 112/112 [==============================] - 9s 75ms/step - loss: 2.6974 - accuracy: 0.0857 - val_loss: 2.6904 - val_accuracy: 0.0961
# Epoch 2/25
# 112/112 [==============================] - 8s 71ms/step - loss: 2.6814 - accuracy: 0.0935 - val_loss: 2.6764 - val_accuracy: 0.1262
# Epoch 3/25
# 112/112 [==============================] - 7s 63ms/step - loss: 2.6556 - accuracy: 0.1205 - val_loss: 2.6428 - val_accuracy: 0.1204
# Epoch 4/25
# 112/112 [==============================] - 7s 66ms/step - loss: 2.5979 - accuracy: 0.1520 - val_loss: 2.5855 - val_accuracy: 0.1736
# Epoch 5/25
# 112/112 [==============================] - 6s 50ms/step - loss: 2.5222 - accuracy: 0.1728 - val_loss: 2.5414 - val_accuracy: 0.1597
# Epoch 6/25
# 112/112 [==============================] - 8s 70ms/step - loss: 2.4652 - accuracy: 0.1935 - val_loss: 2.5173 - val_accuracy: 0.1574
# Epoch 7/25
# 112/112 [==============================] - 7s 59ms/step - loss: 2.4191 - accuracy: 0.2073 - val_loss: 2.5408 - val_accuracy: 0.1562
# Epoch 8/25
# 112/112 [==============================] - 9s 78ms/step - loss: 2.3846 - accuracy: 0.2171 - val_loss: 2.4787 - val_accuracy: 0.1863
# Epoch 9/25
# 112/112 [==============================] - 8s 76ms/step - loss: 2.3489 - accuracy: 0.2323 - val_loss: 2.4285 - val_accuracy: 0.2153
# Epoch 10/25
# 112/112 [==============================] - 8s 70ms/step - loss: 2.3252 - accuracy: 0.2360 - val_loss: 2.4498 - val_accuracy: 0.1921
# Epoch 11/25
# 112/112 [==============================] - 5s 46ms/step - loss: 2.2852 - accuracy: 0.2567 - val_loss: 2.4128 - val_accuracy: 0.2188
# Epoch 12/25
# 112/112 [==============================] - 9s 79ms/step - loss: 2.2527 - accuracy: 0.2635 - val_loss: 2.3877 - val_accuracy: 0.2396
# Epoch 13/25
# 112/112 [==============================] - 7s 66ms/step - loss: 2.2136 - accuracy: 0.2716 - val_loss: 2.4412 - val_accuracy: 0.2257
# Epoch 14/25
# 112/112 [==============================] - 7s 63ms/step - loss: 2.1789 - accuracy: 0.2904 - val_loss: 2.3458 - val_accuracy: 0.2488
# Epoch 15/25
# 112/112 [==============================] - 8s 70ms/step - loss: 2.1479 - accuracy: 0.2978 - val_loss: 2.3517 - val_accuracy: 0.2477
# Epoch 16/25
# 112/112 [==============================] - 9s 79ms/step - loss: 2.1072 - accuracy: 0.3048 - val_loss: 2.3598 - val_accuracy: 0.2523
# Epoch 17/25
# 112/112 [==============================] - 7s 64ms/step - loss: 2.0764 - accuracy: 0.3185 - val_loss: 2.4515 - val_accuracy: 0.2315
# Epoch 18/25
# 112/112 [==============================] - 8s 76ms/step - loss: 2.0472 - accuracy: 0.3244 - val_loss: 2.5211 - val_accuracy: 0.2234
# Epoch 19/25
# 112/112 [==============================] - 7s 64ms/step - loss: 2.0169 - accuracy: 0.3393 - val_loss: 2.2993 - val_accuracy: 0.2674
# Epoch 20/25
# 112/112 [==============================] - 6s 50ms/step - loss: 1.9741 - accuracy: 0.3517 - val_loss: 2.3040 - val_accuracy: 0.2639
# Epoch 21/25
# 112/112 [==============================] - 9s 84ms/step - loss: 1.9409 - accuracy: 0.3742 - val_loss: 2.3048 - val_accuracy: 0.2766
# Epoch 22/25
# 112/112 [==============================] - 6s 55ms/step - loss: 1.9046 - accuracy: 0.3823 - val_loss: 2.2899 - val_accuracy: 0.2882
# Epoch 23/25
# 112/112 [==============================] - 9s 78ms/step - loss: 1.8768 - accuracy: 0.3902 - val_loss: 2.3036 - val_accuracy: 0.2639
# Epoch 24/25
# 112/112 [==============================] - 9s 80ms/step - loss: 1.8291 - accuracy: 0.4065 - val_loss: 2.2485 - val_accuracy: 0.2894
# Epoch 25/25
# 112/112 [==============================] - 8s 71ms/step - loss: 1.7878 - accuracy: 0.4152 - val_loss: 2.2549 - val_accuracy: 0.2905
# Entrenamiento terminado 194.90437841415405 secs
#  1/27 [>.............................] - ETA: 1s - loss: 2.1758 - accuracy: 0.4062
# <ipython-input-6-6ac806f691b4>:127: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_acc = model.evaluate_generator(generator=test_data_gen,
# 27/27 [==============================] - 1s 35ms/step - loss: 2.2720 - accuracy: 0.2870
# Test terminado 1.0410594940185547 secs
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 62, 62, 6)         168
#
#  average_pooling2d_12 (Avera  (None, 31, 31, 6)        0
#  gePooling2D)
#
#  conv2d_13 (Conv2D)          (None, 29, 29, 16)        880
#
#  average_pooling2d_13 (Avera  (None, 14, 14, 16)       0
#  gePooling2D)
#
#  flatten_6 (Flatten)         (None, 3136)              0
#
#  dense_18 (Dense)            (None, 120)               376440
#
#  dense_19 (Dense)            (None, 84)                10164
#
#  dense_20 (Dense)            (None, 15)                1275
#
# =================================================================
# Total params: 388,927
# Trainable params: 388,927
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# <ipython-input-6-6ac806f691b4>:107: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 112/112 [==============================] - 8s 65ms/step - loss: 2.7057 - accuracy: 0.0787 - val_loss: 2.6896 - val_accuracy: 0.0926
# Epoch 2/25
# 112/112 [==============================] - 9s 80ms/step - loss: 2.6914 - accuracy: 0.0913 - val_loss: 2.6885 - val_accuracy: 0.0949
# Epoch 3/25
# 112/112 [==============================] - 7s 65ms/step - loss: 2.6916 - accuracy: 0.0851 - val_loss: 2.6884 - val_accuracy: 0.0914
# Epoch 4/25
# 112/112 [==============================] - 7s 65ms/step - loss: 2.6923 - accuracy: 0.0862 - val_loss: 2.6895 - val_accuracy: 0.0891
# Epoch 5/25
# 112/112 [==============================] - 8s 70ms/step - loss: 2.6912 - accuracy: 0.0879 - val_loss: 2.6872 - val_accuracy: 0.0938
# Epoch 6/25
# 112/112 [==============================] - 7s 65ms/step - loss: 2.6911 - accuracy: 0.0888 - val_loss: 2.6873 - val_accuracy: 0.0938
# Epoch 7/25
# 112/112 [==============================] - 7s 64ms/step - loss: 2.6909 - accuracy: 0.0890 - val_loss: 2.6894 - val_accuracy: 0.0822
# Epoch 8/25
# 112/112 [==============================] - 8s 73ms/step - loss: 2.6919 - accuracy: 0.0879 - val_loss: 2.6901 - val_accuracy: 0.0903
# Epoch 9/25
# 112/112 [==============================] - 9s 77ms/step - loss: 2.6919 - accuracy: 0.0907 - val_loss: 2.6892 - val_accuracy: 0.0891
# Epoch 10/25
# 112/112 [==============================] - 7s 59ms/step - loss: 2.6915 - accuracy: 0.0899 - val_loss: 2.6868 - val_accuracy: 0.0903
# Epoch 11/25
# 112/112 [==============================] - 6s 50ms/step - loss: 2.6907 - accuracy: 0.0907 - val_loss: 2.6908 - val_accuracy: 0.0914
# Epoch 12/25
# 112/112 [==============================] - 8s 73ms/step - loss: 2.6913 - accuracy: 0.0890 - val_loss: 2.6897 - val_accuracy: 0.0914
# Epoch 13/25
# 112/112 [==============================] - 8s 68ms/step - loss: 2.6915 - accuracy: 0.0874 - val_loss: 2.6883 - val_accuracy: 0.0914
# Epoch 14/25
# 112/112 [==============================] - 6s 51ms/step - loss: 2.6913 - accuracy: 0.0879 - val_loss: 2.6875 - val_accuracy: 0.0938
# Epoch 15/25
# 112/112 [==============================] - 7s 62ms/step - loss: 2.6913 - accuracy: 0.0860 - val_loss: 2.6885 - val_accuracy: 0.0926
# Epoch 16/25
# 112/112 [==============================] - 6s 53ms/step - loss: 2.6915 - accuracy: 0.0902 - val_loss: 2.6885 - val_accuracy: 0.0914
# Epoch 17/25
# 112/112 [==============================] - 9s 78ms/step - loss: 2.6905 - accuracy: 0.0904 - val_loss: 2.6880 - val_accuracy: 0.0926
# Epoch 18/25
# 112/112 [==============================] - 6s 52ms/step - loss: 2.6914 - accuracy: 0.0904 - val_loss: 2.6899 - val_accuracy: 0.0926
# Epoch 19/25
# 112/112 [==============================] - 6s 52ms/step - loss: 2.6908 - accuracy: 0.0899 - val_loss: 2.6891 - val_accuracy: 0.0949
# Epoch 20/25
# 112/112 [==============================] - 6s 52ms/step - loss: 2.6913 - accuracy: 0.0860 - val_loss: 2.6880 - val_accuracy: 0.0949
# Epoch 21/25
# 112/112 [==============================] - 9s 78ms/step - loss: 2.6914 - accuracy: 0.0885 - val_loss: 2.6866 - val_accuracy: 0.0949
# Epoch 22/25
# 112/112 [==============================] - 8s 70ms/step - loss: 2.6915 - accuracy: 0.0913 - val_loss: 2.6891 - val_accuracy: 0.0822
# Epoch 23/25
# 112/112 [==============================] - 8s 72ms/step - loss: 2.6908 - accuracy: 0.0865 - val_loss: 2.6897 - val_accuracy: 0.0914
# Epoch 24/25
# 112/112 [==============================] - 9s 79ms/step - loss: 2.6916 - accuracy: 0.0893 - val_loss: 2.6902 - val_accuracy: 0.0880
# Epoch 25/25
# 112/112 [==============================] - 8s 69ms/step - loss: 2.6914 - accuracy: 0.0888 - val_loss: 2.6870 - val_accuracy: 0.0914
# Entrenamiento terminado 188.55258965492249 secs
#  3/27 [==>...........................] - ETA: 0s - loss: 2.6735 - accuracy: 0.0938
# <ipython-input-6-6ac806f691b4>:127: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_acc = model.evaluate_generator(generator=test_data_gen,
# 27/27 [==============================] - 2s 65ms/step - loss: 2.6905 - accuracy: 0.0845
# Test terminado 1.8387644290924072 secs
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 62, 62, 6)         168
#
#  average_pooling2d_14 (Avera  (None, 31, 31, 6)        0
#  gePooling2D)
#
#  conv2d_15 (Conv2D)          (None, 29, 29, 16)        880
#
#  average_pooling2d_15 (Avera  (None, 14, 14, 16)       0
#  gePooling2D)
#
#  flatten_7 (Flatten)         (None, 3136)              0
#
#  dense_21 (Dense)            (None, 120)               376440
#
#  dense_22 (Dense)            (None, 84)                10164
#
#  dense_23 (Dense)            (None, 15)                1275
#
# =================================================================
# Total params: 388,927
# Trainable params: 388,927
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# <ipython-input-6-6ac806f691b4>:107: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 112/112 [==============================] - 9s 73ms/step - loss: 2.6885 - accuracy: 0.0913 - val_loss: 2.6668 - val_accuracy: 0.1065
# Epoch 2/25
# 112/112 [==============================] - 8s 71ms/step - loss: 2.6175 - accuracy: 0.1250 - val_loss: 2.6259 - val_accuracy: 0.1412
# Epoch 3/25
# 112/112 [==============================] - 6s 52ms/step - loss: 2.5444 - accuracy: 0.1708 - val_loss: 2.5736 - val_accuracy: 0.1782
# Epoch 4/25
# 112/112 [==============================] - 6s 50ms/step - loss: 2.4604 - accuracy: 0.2126 - val_loss: 2.5258 - val_accuracy: 0.1655
# Epoch 5/25
# 112/112 [==============================] - 6s 52ms/step - loss: 2.3952 - accuracy: 0.2244 - val_loss: 2.4989 - val_accuracy: 0.2014
# Epoch 6/25
# 112/112 [==============================] - 7s 61ms/step - loss: 2.3655 - accuracy: 0.2441 - val_loss: 2.4932 - val_accuracy: 0.1933
# Epoch 7/25
# 112/112 [==============================] - 8s 70ms/step - loss: 2.3332 - accuracy: 0.2503 - val_loss: 2.4621 - val_accuracy: 0.2049
# Epoch 8/25
# 112/112 [==============================] - 7s 59ms/step - loss: 2.3120 - accuracy: 0.2553 - val_loss: 2.4692 - val_accuracy: 0.2060
# Epoch 9/25
# 112/112 [==============================] - 8s 73ms/step - loss: 2.2845 - accuracy: 0.2657 - val_loss: 2.4522 - val_accuracy: 0.2199
# Epoch 10/25
# 112/112 [==============================] - 9s 85ms/step - loss: 2.2623 - accuracy: 0.2798 - val_loss: 2.4401 - val_accuracy: 0.2141
# Epoch 11/25
# 112/112 [==============================] - 7s 66ms/step - loss: 2.2364 - accuracy: 0.2885 - val_loss: 2.4428 - val_accuracy: 0.2106
# Epoch 12/25
# 112/112 [==============================] - 8s 75ms/step - loss: 2.2142 - accuracy: 0.2930 - val_loss: 2.4282 - val_accuracy: 0.2176
# Epoch 13/25
# 112/112 [==============================] - 8s 71ms/step - loss: 2.1868 - accuracy: 0.3104 - val_loss: 2.4385 - val_accuracy: 0.2222
# Epoch 14/25
# 112/112 [==============================] - 7s 61ms/step - loss: 2.1663 - accuracy: 0.3126 - val_loss: 2.4137 - val_accuracy: 0.2222
# Epoch 15/25
# 112/112 [==============================] - 8s 75ms/step - loss: 2.1403 - accuracy: 0.3191 - val_loss: 2.4118 - val_accuracy: 0.2245
# Epoch 16/25
# 112/112 [==============================] - 8s 69ms/step - loss: 2.1095 - accuracy: 0.3360 - val_loss: 2.4091 - val_accuracy: 0.2431
# Epoch 17/25
# 112/112 [==============================] - 10s 87ms/step - loss: 2.0851 - accuracy: 0.3289 - val_loss: 2.3876 - val_accuracy: 0.2419
# Epoch 18/25
# 112/112 [==============================] - 7s 59ms/step - loss: 2.0578 - accuracy: 0.3435 - val_loss: 2.4122 - val_accuracy: 0.2350
# Epoch 19/25
# 112/112 [==============================] - 8s 72ms/step - loss: 2.0296 - accuracy: 0.3573 - val_loss: 2.3677 - val_accuracy: 0.2535
# Epoch 20/25
# 112/112 [==============================] - 9s 77ms/step - loss: 2.0048 - accuracy: 0.3719 - val_loss: 2.4115 - val_accuracy: 0.2234
# Epoch 21/25
# 112/112 [==============================] - 8s 71ms/step - loss: 1.9750 - accuracy: 0.3764 - val_loss: 2.3525 - val_accuracy: 0.2488
# Epoch 22/25
# 112/112 [==============================] - 8s 72ms/step - loss: 1.9392 - accuracy: 0.3854 - val_loss: 2.3661 - val_accuracy: 0.2384
# Epoch 23/25
# 112/112 [==============================] - 9s 84ms/step - loss: 1.9146 - accuracy: 0.4025 - val_loss: 2.3447 - val_accuracy: 0.2569
# Epoch 24/25
# 112/112 [==============================] - 7s 60ms/step - loss: 1.8807 - accuracy: 0.4138 - val_loss: 2.3757 - val_accuracy: 0.2396
# Epoch 25/25
# 112/112 [==============================] - 9s 78ms/step - loss: 1.8500 - accuracy: 0.4183 - val_loss: 2.3392 - val_accuracy: 0.2454
# Entrenamiento terminado 198.54147148132324 secs
#  3/27 [==>...........................] - ETA: 0s - loss: 2.1872 - accuracy: 0.3021
# <ipython-input-6-6ac806f691b4>:127: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_acc = model.evaluate_generator(generator=test_data_gen,
# 27/27 [==============================] - 3s 106ms/step - loss: 2.3573 - accuracy: 0.2431
# Test terminado 2.865786552429199 secs
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 62, 62, 6)         168
#
#  average_pooling2d_16 (Avera  (None, 31, 31, 6)        0
#  gePooling2D)
#
#  conv2d_17 (Conv2D)          (None, 29, 29, 16)        880
#
#  average_pooling2d_17 (Avera  (None, 14, 14, 16)       0
#  gePooling2D)
#
#  flatten_8 (Flatten)         (None, 3136)              0
#
#  dense_24 (Dense)            (None, 120)               376440
#
#  dense_25 (Dense)            (None, 84)                10164
#
#  dense_26 (Dense)            (None, 15)                1275
#
# =================================================================
# Total params: 388,927
# Trainable params: 388,927
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# <ipython-input-6-6ac806f691b4>:107: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 112/112 [==============================] - 9s 75ms/step - loss: 2.7002 - accuracy: 0.0843 - val_loss: 2.6922 - val_accuracy: 0.0995
# Epoch 2/25
# 112/112 [==============================] - 7s 65ms/step - loss: 2.6874 - accuracy: 0.0997 - val_loss: 2.6832 - val_accuracy: 0.1007
# Epoch 3/25
# 112/112 [==============================] - 9s 84ms/step - loss: 2.6747 - accuracy: 0.0992 - val_loss: 2.6735 - val_accuracy: 0.0856
# Epoch 4/25
# 112/112 [==============================] - 6s 57ms/step - loss: 2.6476 - accuracy: 0.1115 - val_loss: 2.6530 - val_accuracy: 0.1076
# Epoch 5/25
# 112/112 [==============================] - 8s 73ms/step - loss: 2.5949 - accuracy: 0.1542 - val_loss: 2.5985 - val_accuracy: 0.1377
# Epoch 6/25
# 112/112 [==============================] - 11s 97ms/step - loss: 2.5258 - accuracy: 0.1798 - val_loss: 2.5452 - val_accuracy: 0.1667
# Epoch 7/25
# 112/112 [==============================] - 8s 71ms/step - loss: 2.4667 - accuracy: 0.1958 - val_loss: 2.5301 - val_accuracy: 0.1933
# Epoch 8/25
# 112/112 [==============================] - 7s 61ms/step - loss: 2.4000 - accuracy: 0.2090 - val_loss: 2.4834 - val_accuracy: 0.1933
# Epoch 9/25
# 112/112 [==============================] - 9s 79ms/step - loss: 2.3552 - accuracy: 0.2312 - val_loss: 2.4616 - val_accuracy: 0.2072
# Epoch 10/25
# 112/112 [==============================] - 8s 73ms/step - loss: 2.3195 - accuracy: 0.2503 - val_loss: 2.4159 - val_accuracy: 0.2396
# Epoch 11/25
# 112/112 [==============================] - 8s 65ms/step - loss: 2.2802 - accuracy: 0.2486 - val_loss: 2.4073 - val_accuracy: 0.2384
# Epoch 12/25
# 112/112 [==============================] - 6s 57ms/step - loss: 2.2396 - accuracy: 0.2669 - val_loss: 2.3777 - val_accuracy: 0.2396
# Epoch 13/25
# 112/112 [==============================] - 9s 84ms/step - loss: 2.2060 - accuracy: 0.2801 - val_loss: 2.3916 - val_accuracy: 0.2500
# Epoch 14/25
# 112/112 [==============================] - 8s 69ms/step - loss: 2.1730 - accuracy: 0.2916 - val_loss: 2.3221 - val_accuracy: 0.2535
# Epoch 15/25
# 112/112 [==============================] - 8s 68ms/step - loss: 2.1412 - accuracy: 0.3059 - val_loss: 2.3241 - val_accuracy: 0.2558
# Epoch 16/25
# 112/112 [==============================] - 8s 69ms/step - loss: 2.1070 - accuracy: 0.3098 - val_loss: 2.2838 - val_accuracy: 0.2778
# Epoch 17/25
# 112/112 [==============================] - 9s 80ms/step - loss: 2.0639 - accuracy: 0.3284 - val_loss: 2.2783 - val_accuracy: 0.2731
# Epoch 18/25
# 112/112 [==============================] - 7s 60ms/step - loss: 2.0162 - accuracy: 0.3455 - val_loss: 2.3225 - val_accuracy: 0.2512
# Epoch 19/25
# 112/112 [==============================] - 6s 58ms/step - loss: 1.9927 - accuracy: 0.3534 - val_loss: 2.2372 - val_accuracy: 0.2940
# Epoch 20/25
# 112/112 [==============================] - 6s 50ms/step - loss: 1.9441 - accuracy: 0.3685 - val_loss: 2.2418 - val_accuracy: 0.2766
# Epoch 21/25
# 112/112 [==============================] - 6s 58ms/step - loss: 1.9158 - accuracy: 0.3784 - val_loss: 2.3060 - val_accuracy: 0.2662
# Epoch 22/25
# 112/112 [==============================] - 7s 67ms/step - loss: 1.8869 - accuracy: 0.3924 - val_loss: 2.3823 - val_accuracy: 0.2604
# Epoch 23/25
# 112/112 [==============================] - 8s 76ms/step - loss: 1.8220 - accuracy: 0.4152 - val_loss: 2.1846 - val_accuracy: 0.2951
# Epoch 24/25
# 112/112 [==============================] - 8s 73ms/step - loss: 1.7895 - accuracy: 0.4256 - val_loss: 2.2729 - val_accuracy: 0.2755
# Epoch 25/25
# 112/112 [==============================] - 8s 73ms/step - loss: 1.7652 - accuracy: 0.4390 - val_loss: 2.0939 - val_accuracy: 0.3241
# Entrenamiento terminado 199.04006147384644 secs
#  3/27 [==>...........................] - ETA: 0s - loss: 1.9738 - accuracy: 0.3021
# <ipython-input-6-6ac806f691b4>:127: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_acc = model.evaluate_generator(generator=test_data_gen,
# 27/27 [==============================] - 1s 29ms/step - loss: 2.1027 - accuracy: 0.3264
# Test terminado 0.9006762504577637 secs
