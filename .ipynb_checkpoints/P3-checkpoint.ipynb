# %%
import numpy as np
import time
import matplotlib.pyplot as plt
from Datos import Datos
from Datos import codificacion_one_hot
from EstrategiaParticionado import ValidacionSimple, ValidacionCruzada
from Clasificador import Clasificador
from ClasificadorAlgoritmoGenetico import ClasificadorAlgoritmoGenetico

datasets = ['./Datasets/balloons.csv', './Datasets/titanic.csv']

for dataset_name in datasets:

    if dataset_name == './Datasets/balloons.csv':
        poblacion = 25
        epochs = 50
        max_reglas = 3
    else:
        poblacion = 100
        epochs = 75
        max_reglas = 5
        
    datos = Datos(dataset_name)
    
    cols = datos.datos.columns 
    atributos_unicos = []
    print(datos.datos)
    
    for col in cols:
        if col == 'Class':
            break
        atributos_unicos.append(len(np.unique(datos.datos[col])))
    
    datos.datos = codificacion_one_hot(datos.datos)
    print(f"One hot codificado: \n{datos.datos}")
    nom_atributos = datos.nominalAtributos
    dic = datos.diccionarios
    
    seed = 42
    
    simple = ValidacionSimple(1)
    indices = simple.creaParticiones(datos.datos, seed=seed)
    
    indices_train = indices[0].indicesTrain
    indices_test = indices[0].indicesTest
    
    datosTrain = datos.extraeDatos(indices_train)
    datosTest = datos.extraeDatos(indices_test)

    clf = ClasificadorAlgoritmoGenetico(poblacion_size=poblacion, max_reglas=max_reglas, epochs=epochs, pmut=0.02, elitismo=0.02, atributos_unicos=atributos_unicos, seed=seed)
    fitness_medio_list, mejor_fitness_list = clf.entrenamiento(datosTrain, nom_atributos, dic)
    fitness_test = clf.clasifica(datosTest, nom_atributos, dic)
    
    plt.plot(range(epochs), fitness_medio_list, label="Fitness Promedio")
    plt.plot(range(epochs), mejor_fitness_list, label="Mejor Fitness")
    plt.title(f"Fitness Promedio y Mejor del conjunto Train {dataset_name}")
    plt.xlabel("Épocas")
    plt.ylabel("% de acierto (Función de Fitness)")
    plt.grid()
    plt.legend()
    plt.show()
# Out:
#     Color  Size  Act  Age  Class
# 0       1     1    1    0      1
# 1       1     1    1    1      1
# 2       1     1    0    0      1
# 3       1     1    0    1      1
# 4       1     1    1    0      1
# 5       1     1    1    1      1
# 6       1     1    0    0      1
# 7       1     1    0    1      1
# 8       1     0    1    0      0
# 9       1     0    1    1      0
# 10      1     0    0    0      0
# 11      1     0    0    1      0
# 12      0     1    1    0      0
# 13      0     1    1    1      0
# 14      0     1    0    0      0
# 15      0     1    0    1      0
# 16      0     0    1    0      0
# 17      0     0    1    1      0
# 18      0     0    0    0      0
# 19      0     0    0    1      0
# One hot codificado:
#     Color_0  Color_1  Size_0  Size_1  Act_0  Act_1  Age_0  Age_1 Class
# 0     False     True   False    True  False   True   True  False     1
# 1     False     True   False    True  False   True  False   True     1
# 2     False     True   False    True   True  False   True  False     1
# 3     False     True   False    True   True  False  False   True     1
# 4     False     True   False    True  False   True   True  False     1
# 5     False     True   False    True  False   True  False   True     1
# 6     False     True   False    True   True  False   True  False     1
# 7     False     True   False    True   True  False  False   True     1
# 8     False     True    True   False  False   True   True  False     0
# 9     False     True    True   False  False   True  False   True     0
# 10    False     True    True   False   True  False   True  False     0
# 11    False     True    True   False   True  False  False   True     0
# 12     True    False   False    True  False   True   True  False     0
# 13     True    False   False    True  False   True  False   True     0
# 14     True    False   False    True   True  False   True  False     0
# 15     True    False   False    True   True  False  False   True     0
# 16     True    False    True   False  False   True   True  False     0
# 17     True    False    True   False  False   True  False   True     0
# 18     True    False    True   False   True  False   True  False     0
# 19     True    False    True   False   True  False  False   True     0
# Numero de columnas: 9
# Iteración 0: Mejor fitness: 0.4, Fitness promedio: 0.08533333333333333
# Iteración 1: Mejor fitness: 0.4, Fitness promedio: 0.22399999999999998
# Iteración 2: Mejor fitness: 0.4, Fitness promedio: 0.26133333333333336
# Iteración 3: Mejor fitness: 0.4, Fitness promedio: 0.28800000000000003
# Iteración 4: Mejor fitness: 0.5333333333333333, Fitness promedio: 0.28800000000000003
# Iteración 5: Mejor fitness: 0.5333333333333333, Fitness promedio: 0.32533333333333336
# Iteración 6: Mejor fitness: 0.5333333333333333, Fitness promedio: 0.35466666666666674
# Iteración 7: Mejor fitness: 0.5333333333333333, Fitness promedio: 0.33866666666666667
# Iteración 8: Mejor fitness: 0.6, Fitness promedio: 0.3306666666666667
# Iteración 9: Mejor fitness: 0.6, Fitness promedio: 0.36
# Iteración 10: Mejor fitness: 0.8, Fitness promedio: 0.3973333333333333
# Iteración 11: Mejor fitness: 0.8, Fitness promedio: 0.4613333333333333
# Iteración 12: Mejor fitness: 0.8, Fitness promedio: 0.44799999999999995
# Iteración 13: Mejor fitness: 0.8, Fitness promedio: 0.43200000000000005
# Iteración 14: Mejor fitness: 0.8, Fitness promedio: 0.424
# Iteración 15: Mejor fitness: 0.8, Fitness promedio: 0.49333333333333335
# Iteración 16: Mejor fitness: 0.8, Fitness promedio: 0.44
# Iteración 17: Mejor fitness: 0.8, Fitness promedio: 0.5173333333333333
# Iteración 18: Mejor fitness: 0.8, Fitness promedio: 0.544
# Iteración 19: Mejor fitness: 0.8, Fitness promedio: 0.5146666666666666
# Iteración 20: Mejor fitness: 0.8, Fitness promedio: 0.49866666666666665
# Iteración 21: Mejor fitness: 0.8, Fitness promedio: 0.5146666666666666
# Iteración 22: Mejor fitness: 0.8, Fitness promedio: 0.528
# Iteración 23: Mejor fitness: 0.8, Fitness promedio: 0.5226666666666667
# Iteración 24: Mejor fitness: 0.8, Fitness promedio: 0.56
# Iteración 25: Mejor fitness: 0.8, Fitness promedio: 0.5413333333333333
# Iteración 26: Mejor fitness: 0.8, Fitness promedio: 0.512
# Iteración 27: Mejor fitness: 0.8, Fitness promedio: 0.552
# Iteración 28: Mejor fitness: 0.8, Fitness promedio: 0.6426666666666666
# Iteración 29: Mejor fitness: 0.8, Fitness promedio: 0.5733333333333333
# Iteración 30: Mejor fitness: 0.8, Fitness promedio: 0.5626666666666668
# Iteración 31: Mejor fitness: 0.8, Fitness promedio: 0.6373333333333333
# Iteración 32: Mejor fitness: 1.0, Fitness promedio: 0.648
# Iteración 33: Mejor fitness: 1.0, Fitness promedio: 0.6
# Iteración 34: Mejor fitness: 1.0, Fitness promedio: 0.5733333333333334
# Iteración 35: Mejor fitness: 1.0, Fitness promedio: 0.5333333333333333
# Iteración 36: Mejor fitness: 1.0, Fitness promedio: 0.5760000000000001
# Iteración 37: Mejor fitness: 1.0, Fitness promedio: 0.512
# Iteración 38: Mejor fitness: 1.0, Fitness promedio: 0.5493333333333333
# Iteración 39: Mejor fitness: 1.0, Fitness promedio: 0.5946666666666666
# Iteración 40: Mejor fitness: 1.0, Fitness promedio: 0.568
# Iteración 41: Mejor fitness: 1.0, Fitness promedio: 0.6106666666666666
# Iteración 42: Mejor fitness: 1.0, Fitness promedio: 0.6933333333333332
# Iteración 43: Mejor fitness: 1.0, Fitness promedio: 0.6986666666666668
# Iteración 44: Mejor fitness: 1.0, Fitness promedio: 0.6666666666666667
# Iteración 45: Mejor fitness: 1.0, Fitness promedio: 0.6693333333333333
# Iteración 46: Mejor fitness: 1.0, Fitness promedio: 0.6346666666666667
# Iteración 47: Mejor fitness: 1.0, Fitness promedio: 0.6026666666666667
# Iteración 48: Mejor fitness: 1.0, Fitness promedio: 0.6773333333333332
# Iteración 49: Mejor fitness: 1.0, Fitness promedio: 0.504
# Mejor Fitness: 1.0
# Mejor Individuo: [bitarray('011011110'), bitarray('101111110'), bitarray('111111111')]
# Fitness en Test: [1.0]
#       Pclass  Sex  Age  Class
# 0          2    1    3      1
# 1          2    1    6      1
# 2          3    0    4      0
# 3          3    0    0      0
# 4          1    1    9      1
# ...      ...  ...  ...    ...
# 1041       3    1    3      0
# 1042       3    1    8      0
# 1043       3    0    4      1
# 1044       3    1    4      0
# 1045       2    1    3      0
#
# [1046 rows x 4 columns]
# One hot codificado:
#       Pclass_1  Pclass_2  Pclass_3  Sex_0  Sex_1  Age_0  Age_1  Age_2  Age_3  \
# 0        False      True     False  False   True  False  False  False   True
# 1        False      True     False  False   True  False  False  False  False
# 2        False     False      True   True  False  False  False  False  False
# 3        False     False      True   True  False   True  False  False  False
# 4         True     False     False  False   True  False  False  False  False
# ...        ...       ...       ...    ...    ...    ...    ...    ...    ...
# 1041     False     False      True  False   True  False  False  False   True
# 1042     False     False      True  False   True  False  False  False  False
# 1043     False     False      True   True  False  False  False  False  False
# 1044     False     False      True  False   True  False  False  False  False
# 1045     False      True     False  False   True  False  False  False   True
#
#       Age_4  ...  Age_7  Age_8  Age_9  Age_10  Age_11  Age_12  Age_13  Age_14  \
# 0     False  ...  False  False  False   False   False   False   False   False
# 1     False  ...  False  False  False   False   False   False   False   False
# 2      True  ...  False  False  False   False   False   False   False   False
# 3     False  ...  False  False  False   False   False   False   False   False
# 4     False  ...  False  False   True   False   False   False   False   False
# ...     ...  ...    ...    ...    ...     ...     ...     ...     ...     ...
# 1041  False  ...  False  False  False   False   False   False   False   False
# 1042  False  ...  False   True  False   False   False   False   False   False
# 1043   True  ...  False  False  False   False   False   False   False   False
# 1044   True  ...  False  False  False   False   False   False   False   False
# 1045  False  ...  False  False  False   False   False   False   False   False
#
#       Age_15  Class
# 0      False      1
# 1      False      1
# 2      False      0
# 3      False      0
# 4      False      1
# ...      ...    ...
# 1041   False      0
# 1042   False      0
# 1043   False      1
# 1044   False      0
# 1045   False      0
#
# [1046 rows x 22 columns]
# Numero de columnas: 22
# Iteración 0: Mejor fitness: 0.5663265306122449, Fitness promedio: 0.1571428571428571
# Iteración 1: Mejor fitness: 0.5663265306122449, Fitness promedio: 0.2614295718287315
# Iteración 2: Mejor fitness: 0.5931122448979592, Fitness promedio: 0.3195398351648352
# Iteración 3: Mejor fitness: 0.5931122448979592, Fitness promedio: 0.36886311128224875
# Iteración 4: Mejor fitness: 0.5931122448979592, Fitness promedio: 0.39986063869992444
# Iteración 5: Mejor fitness: 0.5931122448979592, Fitness promedio: 0.40691094619666046
# Iteración 6: Mejor fitness: 0.5982142857142857, Fitness promedio: 0.4369077988338193
# Iteración 7: Mejor fitness: 0.6045918367346939, Fitness promedio: 0.42268617973505196
# Iteración 8: Mejor fitness: 0.6045918367346939, Fitness promedio: 0.4276587790288529
# Iteración 9: Mejor fitness: 0.6045918367346939, Fitness promedio: 0.4441477862331374
# Iteración 10: Mejor fitness: 0.7257653061224489, Fitness promedio: 0.45093537414965984
# Iteración 11: Mejor fitness: 0.7257653061224489, Fitness promedio: 0.44648084643693536
# Iteración 12: Mejor fitness: 0.7257653061224489, Fitness promedio: 0.4650057603686636
# Iteración 13: Mejor fitness: 0.7257653061224489, Fitness promedio: 0.4810495626822158
# Iteración 14: Mejor fitness: 0.735969387755102, Fitness promedio: 0.48806202168367346
# Iteración 15: Mejor fitness: 0.735969387755102, Fitness promedio: 0.49183673469387756
# Iteración 16: Mejor fitness: 0.735969387755102, Fitness promedio: 0.49079120284477434
# Iteración 17: Mejor fitness: 0.735969387755102, Fitness promedio: 0.4883109960402071
# Iteración 18: Mejor fitness: 0.7372448979591837, Fitness promedio: 0.4891206482593037
# Iteración 19: Mejor fitness: 0.7423469387755102, Fitness promedio: 0.4880675096125407
# Iteración 20: Mejor fitness: 0.7423469387755102, Fitness promedio: 0.5036352040816325
# Iteración 21: Mejor fitness: 0.7423469387755102, Fitness promedio: 0.4813703650474275
# Iteración 22: Mejor fitness: 0.7423469387755102, Fitness promedio: 0.4820985685941043
# Iteración 23: Mejor fitness: 0.7423469387755102, Fitness promedio: 0.5145810036343306
# Iteración 24: Mejor fitness: 0.7423469387755102, Fitness promedio: 0.5142202151130723
# Iteración 25: Mejor fitness: 0.7423469387755102, Fitness promedio: 0.5123554421768708
# Iteración 26: Mejor fitness: 0.7525510204081632, Fitness promedio: 0.5060502819548872
# Iteración 27: Mejor fitness: 0.7525510204081632, Fitness promedio: 0.515388947786907
# Iteración 28: Mejor fitness: 0.7525510204081632, Fitness promedio: 0.5219861983254841
# Iteración 29: Mejor fitness: 0.7525510204081632, Fitness promedio: 0.513191035908034
# Iteración 30: Mejor fitness: 0.7525510204081632, Fitness promedio: 0.4942442602040817
# Iteración 31: Mejor fitness: 0.7525510204081632, Fitness promedio: 0.503385613504661
# Iteración 32: Mejor fitness: 0.7525510204081632, Fitness promedio: 0.4919658412145347
# Iteración 33: Mejor fitness: 0.7525510204081632, Fitness promedio: 0.48162035898696826
# Iteración 34: Mejor fitness: 0.7525510204081632, Fitness promedio: 0.48502793974732744
# Iteración 35: Mejor fitness: 0.764030612244898, Fitness promedio: 0.4904111644657863
# Iteración 36: Mejor fitness: 0.764030612244898, Fitness promedio: 0.4936521120075938
# Iteración 37: Mejor fitness: 0.764030612244898, Fitness promedio: 0.509976835561811
# Iteración 38: Mejor fitness: 0.7653061224489796, Fitness promedio: 0.5266262755102041
# Iteración 39: Mejor fitness: 0.7691326530612245, Fitness promedio: 0.5144462279293741
# Iteración 40: Mejor fitness: 0.7691326530612245, Fitness promedio: 0.5270266439909297
# Iteración 41: Mejor fitness: 0.7729591836734694, Fitness promedio: 0.5461566494729759
# Iteración 42: Mejor fitness: 0.7729591836734694, Fitness promedio: 0.5275274511978705
# Iteración 43: Mejor fitness: 0.7729591836734694, Fitness promedio: 0.5182411674347158
# Iteración 44: Mejor fitness: 0.7729591836734694, Fitness promedio: 0.5261547438124186
# Iteración 45: Mejor fitness: 0.7755102040816326, Fitness promedio: 0.5172328141783028
# Iteración 46: Mejor fitness: 0.7755102040816326, Fitness promedio: 0.5123830782312925
# Iteración 47: Mejor fitness: 0.7755102040816326, Fitness promedio: 0.5271407532084998
# Iteración 48: Mejor fitness: 0.7755102040816326, Fitness promedio: 0.5337814972927947
# Iteración 49: Mejor fitness: 0.7755102040816326, Fitness promedio: 0.5184948979591837
# Iteración 50: Mejor fitness: 0.7780612244897959, Fitness promedio: 0.5088775510204081
# Iteración 51: Mejor fitness: 0.7780612244897959, Fitness promedio: 0.5046158314811073
# Iteración 52: Mejor fitness: 0.7780612244897959, Fitness promedio: 0.5043142256902761
# Iteración 53: Mejor fitness: 0.7869897959183674, Fitness promedio: 0.49606201703982555
# Iteración 54: Mejor fitness: 0.7869897959183674, Fitness promedio: 0.5114734595761382
# Iteración 55: Mejor fitness: 0.7920918367346939, Fitness promedio: 0.5310920796890184
# Iteración 56: Mejor fitness: 0.7920918367346939, Fitness promedio: 0.5247641509433962
# Iteración 57: Mejor fitness: 0.7920918367346939, Fitness promedio: 0.51925781995041
# Iteración 58: Mejor fitness: 0.7920918367346939, Fitness promedio: 0.5249551209372638
# Iteración 59: Mejor fitness: 0.8010204081632653, Fitness promedio: 0.5242756506272234
# Iteración 60: Mejor fitness: 0.8010204081632653, Fitness promedio: 0.5173817254174397
# Iteración 61: Mejor fitness: 0.8010204081632653, Fitness promedio: 0.5195578231292516
# Iteración 62: Mejor fitness: 0.8010204081632653, Fitness promedio: 0.52738930393586
# Iteración 63: Mejor fitness: 0.8010204081632653, Fitness promedio: 0.5310976160375654
# Iteración 64: Mejor fitness: 0.8035714285714286, Fitness promedio: 0.531015037593985
# Iteración 65: Mejor fitness: 0.8035714285714286, Fitness promedio: 0.5258595829636202
# Iteración 66: Mejor fitness: 0.8035714285714286, Fitness promedio: 0.5193140833919775
# Iteración 67: Mejor fitness: 0.8035714285714286, Fitness promedio: 0.5098715768358626
# Iteración 68: Mejor fitness: 0.8035714285714286, Fitness promedio: 0.5119335869941197
# Iteración 69: Mejor fitness: 0.8035714285714286, Fitness promedio: 0.505889855942377
# Iteración 70: Mejor fitness: 0.8035714285714286, Fitness promedio: 0.5149234693877551
# Iteración 71: Mejor fitness: 0.8035714285714286, Fitness promedio: 0.5082591921065948
# Iteración 72: Mejor fitness: 0.8035714285714286, Fitness promedio: 0.5040356306457009
# Iteración 73: Mejor fitness: 0.8035714285714286, Fitness promedio: 0.5093641114982578
# Iteración 74: Mejor fitness: 0.8061224489795918, Fitness promedio: 0.5296196099407504
# Mejor Fitness: 0.8061224489795918
# Mejor Individuo: [bitarray('1101010000001110110011'), bitarray('0101011001101100110101'), bitarray('1110101111111111111100'), bitarray('0011111000110110011000'), bitarray('1111111111111111010011')]
# Fitness en Test: [0.7824427480916031]

# %% [markdown]
# # Apartado 1
#
# Breve descripción de algunos detalles de la implementación.
# Solo es necesario especificar los siguientes aspectos:
# a) Mecanismo/s de cruce implementado
# b) Mecanismo/s de mutación implementado
#
# Se ha implementado un mecanismo de cruce intra-reglas, donde se elige aleatoriamente una regla de cada progenitor y un punto de cruce. El punto de cruce determina que parte de las reglas que se intercambiarán entre los progenitores, en concreto, todo lo que quede a la derecha del punto de cruce será intercambiado entre los progenitores, y para mantener la semántica se establece la misma posición del punto de cruce para ambas reglas.
#
# Para el mecanismo de mutación se ha implimentado una mutación estándar aplicada a todas las reglas, es decir para todas las reglas de individuo se reccoren bit a bit aplicando una mutación (cambiando el valor del bit) según una probabilidad dada.

# %% [markdown]
# # Apartado 2
#
# Resultados de la clasificación para cada uno de los dos conjuntos
# de prueba. Indicar con qué combinación de
# individuos/generaciones se consigue el mejor resultado.
# Además del porcentaje de acierto o error, deberá incluirse en
# el notebook el conjunto de reglas correspondiente al mejor
# individuo, así como una interpretación del significado de
# dichas reglas.

# %% [markdown]
# # Apartado 3
#
# Análisis de resultados: importancia del número de reglas, tamaño
# de la población, generaciones

# %% [markdown]
# # Apartado 4
#
# Solo para la fase de entrenamiento, evolución en forma de gráfica:
# a) Del fitness del mejor individuo de la población
# b) Del fitness medio de la población
